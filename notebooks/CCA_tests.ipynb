# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import netCDF4 as nc
import xarray as xr
import os
from pathlib import Path
from numpy import nanmedian
import scipy
import scipy.signal
import math
from numpy.fft import fft2
import cmocean
import cv2
import matplotlib
plt.rcParams["figure.figsize"] = 14, 12
# %matplotlib inline

# %%
def get_data(data):
    
    """
    function to get our netCDF file that is stored in the data directory and convert it to a dataframe.
    The data parameter is the string name of the netCDF file we want to import
    """
    
    current_path = os.getcwd()
    data_folder = os.path.join(current_path,"../data")
    
    nc_path = os.path.join(data_folder, data)
    ds = nc.Dataset(nc_path)
    netCDF = xr.load_dataset(nc_path)
    
    df = netCDF.to_dataframe()
    df = df.reset_index()
    
    df = df.drop(['depth'], axis=1, errors='ignore') #drop the column 'depth' if exists: only exists in reanalysis
    
    #caso se esteja a importar os dados do MUR, renomear as colunas e passar a temperatura para Celsius
    if data.startswith('mur'):
        df.rename(columns={'lat': 'latitude', 'lon': 'longitude', 'time': 'time', 'analysed_sst':'thetao'}, inplace=True)
        df['thetao'] = df['thetao']-273.15   
        
    
    return df

# %%
df_mur_aug = get_data('murAugust2019.nc')

# %%
df_mur_aug
# Out:
#           latitude  longitude                time     thetao
# 0             35.0      -19.0 2019-08-01 09:00:00  22.830994
# 1             35.0      -19.0 2019-08-02 09:00:00  23.727997
# 2             35.0      -19.0 2019-08-03 09:00:00  24.345001
# 3             35.0      -19.0 2019-08-04 09:00:00  24.382996
# 4             35.0      -19.0 2019-08-05 09:00:00  24.256012
# ...            ...        ...                 ...        ...
# 43474426      45.0       -5.0 2019-08-27 09:00:00  19.819000
# 43474427      45.0       -5.0 2019-08-28 09:00:00  20.588013
# 43474428      45.0       -5.0 2019-08-29 09:00:00  20.716003
# 43474429      45.0       -5.0 2019-08-30 09:00:00  20.743988
# 43474430      45.0       -5.0 2019-08-31 09:00:00  20.885010
#
# [43474431 rows x 4 columns]

# %%
#Sacar dados do MUR para um só dia para testar o algoritmo Cayulla-Cornillon no MATLAB e Python
Aug1_mur = df_mur_aug[df_mur_aug['time'] == '2019-08-01 09:00:00']

# %%
Aug15_mur = df_mur_aug[df_mur_aug['time'] == '2019-08-15 09:00:00']

# %%
#Não faz sentido ter isto em função

def get_period(df):
    
    """
    Function that receives a dataframe that can have data relative to different days 
    and returns a dictionaire of dataframes (for each different day) (days) and an array with the different dates 
    its possible to find in our dataframe (specificday)
    """
    
    specificday = [pd.Timestamp(dd).strftime("%Y-%m-%d %H:%M:%S") for dd in df['time'].unique()]
    specificday = np.array(specificday, dtype=np.object)
  
    #create a dictionary to store the data frames for each day
    days = {elem : pd.DataFrame for elem in specificday}

    for key in days.keys():
        days[key] = df[:][df['time'] == key]
        
    return days, specificday

#after this function we only have to define the period we want to analyse

# %%
days_mur_aug, specificday_mur_aug = get_period(df_mur_aug)
#specificday_mur_aug -> array com as datas relativas ao periodo em questão
#days_mur_aug -> dicionairo de dataframes com dados para as datas relativas ao periodo em questão

# %%
def getFrontInWindow(w, head, minTheta, minPopProp, minPopMeanDiff, minSinglePopCohesion, 
                     minGlobalPopCohesion, corners):
    
    #empty arrays de xdata, ydata e z
    xdata = np.array([])
    ydata = np.array([])
    z = np.array([])
    exitType=0
    
    #mask is an array with the same shape of w, that is 1 if in that index position w = np.nan and 0 otherwise
    mask = np.isnan(w).astype('int')  
    haveNaNs = np.any(mask[:]).astype('int')  #haveNaNs=1 if mask has 1s (that correspond to NaNs in matrix w)
    n_NaNs=0
    
    
    if haveNaNs:
        n_NaNs = sum(mask.flatten()[:])       # count nr of 1s (NaNs in matrix w) that there are
        if (n_NaNs/len(w.flatten())>0.5):     #window can't have more than 50% of its pixels as NaNs
            exitType=-1
            return None,None,None,exitType  
        
    mi_ma = [np.nanmin(w), np.nanmax(w)]                          #array with minimum and maximum value of w
    n = math.ceil((mi_ma[1]-mi_ma[0])/0.02)                       #number of bins
    bins = np.arange(mi_ma[0], mi_ma[1], 0.02)                    #to define the bins sequence 
    [y, xout] = np.histogram(w[:], bins, mi_ma)                   #y->frequency counts, Xout->bin location
    xout = np.mean(np.vstack([xout[0:-1],xout[1:]]), axis=0)     #xout to be relative to the centers of the bins
    
    
    thresValue = xout[0]        
    totalCount = len(w.flatten()) - n_NaNs    #nr of non NaN pixels 
    threshPopACount = 0
    threshSeparation = -1
    threshPopAMean = 0
    threshPopBMean = 0
    
    w[mask==1] = 0                      #Replace NaNs with 0's (when mask is 1 replace values of array w for 0)
    totalSum = sum(w.flatten())                      #sum of values of matrix w
    totalSumSquares = sum(w.flatten()*w.flatten())   #sum of the squares of the values of w
    
    #In this for loop we are going to discover which line is going to make the best separation between the average
    # of population on the left and on the right (A and B) - and that is going to be the thresValue
    for k in range(1,n-1):     #ignore the first and last candidates (senão seria de 0 a n)
        popASum = sum(y[0:k+1] * xout[0:k+1])    
        popBSum = sum(y[k+1:] * xout[k+1:])  
        popACount = sum(y[0:k+1])     #sum of frequencies (y) from populationA
        popBCount = sum(y[k+1:])      #sum of frequencies (y) from populationB
    
        popAMean = popASum/popACount
        try:                                  #try to avoid the zerodivisionerror that was poping up 
            popBMean = popBSum/popBCount
        except ZeroDivisionError:
            popBMean = 0
        separation = popACount * popBCount * (popAMean - popBMean) * (popAMean - popBMean)
        if separation>threshSeparation:
            threshSeparation = separation
            thresValue = xout[k]
            threshPopACount = popACount
            threshPopAMean = popAMean
            threshPopBMean = popBMean
            
         
        #abort in case the proportion of population A is less that a certain minimum
    if (threshPopACount / totalCount < minPopProp):
        exitType = 1
        return None,None, None, exitType  
    
    #abort in case the proportion of population B is less that a certain minimum
    if (1.0 - threshPopACount / totalCount < minPopProp):
        exitType = 1
        return None,None,None, exitType  
    
    #abort this window if the difference in the populations means is less than a minimum value
    if (threshPopBMean - threshPopAMean < minPopMeanDiff):   
        exitType = 2
        return None,None,None,exitType  
    
    #Calculate the criterion function THETA (TAUopt) in page 72 of the paper
    totalMean = totalSum/totalCount
    variance = totalSumSquares - (totalMean * totalMean * totalCount)
    theta = threshSeparation / (variance * totalCount)
    if (theta < minTheta):         #abort if theta is lower than a certain minimum  
        exitType = 3
        return None,None,None,exitType  
    
#Cohesion - now that we know the separation value. Based on this value we will check the matrix element by 
#element, and check whether is bigger or lower than the separation  
#we check if it's bigger bellow or to the right (when its bigger we add from one side, when its lower add to the other)
#Count the nr of times a population A cell is immediately adjacent to another popA cell and the same for popB
# A cell can be adjacent on 4 sides. Count only 2 of them (bottom and right side) because doing all 4 would be
#redundant. Do not count diagonal neighbors
    countANextToA = 0
    countBNextToB = 0
    countANextToAOrB = 0
    countBNextToAOrB = 0
    [n_rows, n_cols] = w.shape
    for col in range(0, n_cols-1):
        for row in range(0, n_rows-1):
            if (haveNaNs & (mask[row, col] | mask[row+1, col] | mask[row, col+1])):
                continue
                         
            #examine the bottom neighbor
            if (w[row, col] <= thresValue):                  #if matrix pixel < than the element of separation
                countANextToAOrB = countANextToAOrB + 1      #increase by 1 countANextToAOrB
                if (w[row+1, col] <= thresValue):            #if pixel of bottom row < than separation
                    countANextToA = countANextToA + 1        #increase countANextToA
            else:                                            #if pixel > than separation 
                countBNextToAOrB = countBNextToAOrB + 1      #increase countBNextToAOrB
                if (w[row+1, col] > thresValue):             #if pixel of bellow row > separation
                    countBNextToB = countBNextToB + 1        #increase countBNextToB
                         
                         
            # Examine the right neighbor
            if (w[row, col] <= thresValue):                     #if matrix pixel < separation      
                countANextToAOrB = countANextToAOrB + 1         # increase countANextToAOrB
                if (w[row, col+1] <= thresValue):               #if right pixel < separation
                    countANextToA = countANextToA + 1           # increase countANextToA
            else:                                               #if matrix pixel > separation
                countBNextToAOrB = countBNextToAOrB + 1         #increase countBNextToAOrB
                if (w[row, col+1] > thresValue):                #if right pixel > separation
                    countBNextToB = countBNextToB +1            # increase countBNextToB
                         
                         
    popACohesion = countANextToA / countANextToAOrB
    popBCohesion = countBNextToB/ countBNextToAOrB
    globalCohesion = (countANextToA + countBNextToB) / (countANextToAOrB + countBNextToAOrB)
    
    #These ifs are in case of errors (parameters below certain limits)
    if (popACohesion < minSinglePopCohesion):
        exitType = 4
        return None, None,None,exitType  
                         
    if (popBCohesion < minSinglePopCohesion):
        exitType = 4
        return None, None, None,exitType  
                         
    if (globalCohesion < minGlobalPopCohesion):
        exitType = 4
        return None, None, None,exitType  
                         
                         
    #OK if we reach here we have a front. Compute its contour
    X = np.linspace(head[0], head[1], n_cols)    
    Y = np.linspace(head[2], head[3], n_rows)
    if (corners.size == 0):
        w = w.astype('double')    
        if haveNaNs:
            w[w==0] = np.nan      # Need to restore the NaNs to not invent new contours around zeros
        
        c = plt.contour(X, Y, w, [thresValue])    #Create and store a set of contour lines or filled regions.
    else:
        #the 4 corners have these indices [17,32,17,32; 17,32,1,16; 1,16,1,16;1,16,17,32]
        # and the variable corners has one of its rows (the current to be retained sub-window)
        
        X = X[np.arange(corners[2]-1, corners[3])]
        Y = Y[np.arange(corners[0]-1, corners[1])]
        w = w[np.arange(corners[0], corners[1]).min()-1:np.arange(corners[0], corners[1]).max()+1, np.arange(corners[2], corners[3]).min()-1:np.arange(corners[2], corners[3]).max()+1]
        
        if  haveNaNs:
            w[w==0] = np.nan     # Need to restore the NaNs to not invent new contours around zeros
                         
        if (np.isnan(w)).all()==True:
            c = np.array([])
        else:
            c = plt.contour(X, Y, w, [thresValue])     #Create and store a set of contour lines or filled regions.
                     
                
        
        M = c.allsegs[:]          #list of arrays for contour c. Each array corresponds to a line that may or may
                                    #not be drawn. This list can have any number of arrays
            
        M = [x for x in M if x]   #if the list has empty arrays we will drop them
        
        count = 0   #to iterate through the various arrays
        
        #Create list of booleans (True or False) wether the conditions bellow are fulfilled
        # Each array (line of contour) must have more that 7 data points and they can't be closed lines
        lista = []     
        for i in range(len(M[:])):
            lista.append([(len(x)<7 or (x[0][0]==x[-1][0] and x[0][1] == x[-1][1])) for x in M[:][i]])
            
            #if False the line will be drawn
            #if True the line will be ignored
            
        for value in lista:
            if value == [True]:
                continue        #return to the top of the for loop
            else:
        
                #For the first array of M we will take all the values of x and put them into an array
                x = []
                for i in range(len(M[:][count][0])):
                    x.append((M[:][count][0][i][0]).round(4))
                
                #For the first array of M we will take all the values of y and put them into an array
                y = []
                for i in range(len(M[:][count][0])):
                    y.append((M[:][count][0][i][1]).round(4))
                
                
                #save the x and y data points for each line in an xdata and ydata array
                xdata = np.append(xdata, x)    
                ydata = np.append(ydata, y)
        
                #each soon to be drawn line is separated by an np.nan value
                xdata = np.append(xdata, np.nan)
                ydata = np.append(ydata, np.nan)
                    
                count = count + 1
            
        
        z = thresValue
        
        if (xdata.size == 0):
            exitType = 5;
            
    return xdata, ydata, z, exitType

# %%
def CCA_SIED(df):
    """
    df - dataframe onde vai ser aplicado o CCA_SIED. Esta dataframe tem uma coluna com valores de latitude
    de longitude e de sst
    """
    
    #convert the latitude and longitude columns to a numpy array
    lat = df['latitude'].to_numpy()
    lon = df['longitude'].to_numpy()
    
    lat = np.unique(lat).round(3)        #get the unique values of the latitude array
    lon = np.unique(lon).round(3)        #get the unique values of the longitude array
    
    #get the sst values as a grid acording to the longitude (nr of rows) and latitude (nr of columns)
    sst = df.pivot_table(index='longitude', columns='latitude', values='thetao').values.round(4)
    
    lat_min = lat.min()     
    lat_max = lat.max()
    lon_min = lon.min()
    lon_max = lon.max()
    
    extent = [lon_min, lon_max, lat_min, lat_max]   # for visualization in the plt.imshow()

    lat_unique = len(np.unique(lat))    # nr of different latitude points
    lon_unique = len(np.unique(lon))    #nr of different longitude points

    X = np.linspace(lon_min, lon_max, lon_unique)        #linearly spaced vector with the longitude points
    Y = np.linspace(lat_min, lat_max, lat_unique)        #linearly spaced vector with the latitude points
    X, Y = np.meshgrid(X, Y)                 #create a rectangular grid out of two given one-dimensional arrays

    lat, lon = np.meshgrid(lat, lon)            

    from scipy.interpolate import griddata
    Z = griddata((lon.flatten(), lat.flatten()), sst.flatten(), (X,Y), method='linear')  
    
    head = np.array([lon_min, lon_max])           #Extremos do array que se obtem com a meshgrid em X
    head = np.append(head, [lat_min, lat_max])   #Extremos do array que se obtem com a meshgrid em Y

    z_dim = Z.shape    #dimensões da matriz Z (rows, cols)

    z_actual_range = np.array([np.nanmin(Z[:]), np.nanmax(Z[:])])    #range dos dados (valor minimo e maximo da matriz Z)
    nx = z_dim[1]      # number of columns of matrix Z
    ny = z_dim[0]      # number of rows of matrix Z
    node_offset = 0
    
    #index 4 -> menor valor de Z; index5 -> maior valor de Z; index6 -> node_offset=0
    head = np.append(head, np.array([z_actual_range[0], z_actual_range[1] , node_offset]))    
    head = np.append(head, np.array((head[1]- head[0])/(nx - int(not node_offset))))     #index 7 -> quociente da diferença dos extremos da meshgrid em X e o nr de colunas-1
    head = np.append(head, np.array((head[3]- head[2])/(ny - int(not node_offset))))     #index 8 -> quociente da diferença dos extremos da meshgrid em Y e o nr de rows-1
    head = head.astype('float')

    
    #cayula
    minPopProp = 0.20        #minimum proportion of each population
    minPopMeanDiff = 0.4     # minimum difference between the means of the 2 populations
    minTheta = 0.70
    minSinglePopCohesion = 0.90
    minGlobalPopCohesion = 0.70
    
    
    [n_rows, n_cols] = Z.shape       #nr de rows e nr de columns da matriz Z
    winW16 = 16
    winW32 = 16*2
    winW48 = 16*3


    #arrays that will store the contour of every front that will be detected
    xdata_final = np.array([])
    ydata_final = np.array([])

    s=0 #s=1 means subwindows do NOT share a common border. With s = 0 they do.

    xSide16 = winW16*head[7]
    ySide16 = winW16*head[8]
    xSide32 = (winW32 - s) * head[7]
    ySide32 = (winW32 - s) * head[8]

    nWinRows = math.floor(n_rows/winW16)   #times a window can slide over the rows 
    nWinCols = math.floor(n_cols/winW16)   #times a window can slide over the columns


    for wRow in range(1, nWinRows-1):    
        #start and stop indices and coords of current window
        r1 = (wRow-1) * winW16 + 1
        r2 = r1 + winW48 -s     
    
        y0 = head[2] + (wRow-1)*ySide16    #y1 = y0 + (winW48-1)*head[8]
    
        for wCol in range(1, nWinCols-1):     
            c1 = (wCol - 1)*winW16+1
            c2 = c1 + winW48 - s
            x0 = head[0] + (wCol-1) * xSide16     #x1 = x0 + (winW48-1)*head[7]
            wPad = Z[r1-1:r2, c1-1:c2]            # 49x49 (or 48x48 if s == 1) Window
        
            rr = np.array([1,1,2,2])
            cc = np.array([1,2,2,1])
        
            if s==1:
                corners = np.array([[17, 32, 17, 32], [17, 32, 1, 16], [1, 16, 1, 16], [1, 16, 17, 32]])  #less good
            else:
                corners = np.array([[17, 33, 17, 33], [17, 33, 1, 17], [1, 17, 1, 17], [1, 17, 17, 33]])
            
            for k in range(0,4):     #loop over the 4 slidding 32X32 sub-windows of the larger 48x48 one
                m1 = (rr[k] - 1) * winW16 + 1
                m2 = m1 + 2 * winW16 - s             #indices of the slidding 33X33 window
                n1 = (cc[k] - 1) * winW16 + 1
                n2 = n1 + 2 * winW16 - s
            
                w = wPad[m1-1:m2, n1-1:n2].astype('double')      #sub window with size 33x33
            
                #corners coordinates
                subWinX0 = x0 + (cc[k] - 1) * xSide16
                subWinX1 = subWinX0 + xSide32
                subWinY0 = y0 + (rr[k] - 1) * ySide16
                subWinY1 = subWinY0 + ySide32
            
                R = np.array([subWinX0, subWinX1, subWinY0, subWinY1])
          
                xdata, ydata, z, exitType = getFrontInWindow(w, R, minTheta, minPopProp, minPopMeanDiff, minSinglePopCohesion, minGlobalPopCohesion, corners[k,:])
            
                if (exitType == 0):
                   
                    xdata_final = np.append(xdata_final, xdata)
                
                    ydata_final = np.append(ydata_final,ydata)
    
    
    
    #plt.plot(xdata_final, ydata_final, color="red", linewidth=0.5)
    #plt.imshow(np.flipud(Z), extent=extent)
    #plt.rcParams["figure.figsize"] = 12, 8
    #plt.colorbar(fraction=0.036, pad=0.04)
    #plt.show()
    
    return xdata_final, ydata_final

# %%
def CCA_visualization(period, days):
    
    """
    Function that allows the visualization of the aplication of the Cayula-Cornillon Algorithm (CCA) on several 
    images. It receives 2 parameters: period (its an array with the several dates for the period in question) and
    days (which is a dictionaire of dataframes) with data related. This 2 arguments are obtained with function
    get_period()
    """
    
    #to define the extent in order for the map coordinates became well defined
    
    lat = days[period[0]]['latitude'].to_numpy()
    lon = days[period[0]]['longitude'].to_numpy()
    lat = np.unique(lat).round(3)
    lon = np.unique(lon).round(3)

    lat_min = lat.min()     
    lat_max = lat.max()
    lon_min = lon.min()
    lon_max = lon.max()

    extent = [lon_min, lon_max, lat_min, lat_max]
    
    
    
    #Create a masked_array for the study zone in order to get the continental zone well defined
    
    #Convert some df to a numpy array with the SST values for each value of longitude and latitude
    sst = days[period[0]].pivot_table(index='longitude', columns='latitude', values='thetao').T.values    
    mask = np.isnan(np.flipud(sst))    #Boolean array is True where original array (Temp) had Null values
    mask255 =np.where(mask,(np.ones(mask.shape))*255,0).astype("uint8")   #array which pixels = 255 when mask=True
    #Make a dilation to ensure the pixels that belong to the shore are not consideredd fronts
    kernel = np.ones((3,3), np.uint8)
    mask_dilated = cv2.dilate(mask255, kernel)


    #2 empty arrays that will store the x and y values of the lines that are suposed to be drawn
    x = np.array([])
    y = np.array([])

    for day in period:                                   #period -> specificday_mur_aug for example
        xdata_final, ydata_final = CCA_SIED(days[day])        #days -> days_mur_aug for example
        x = np.append(x, xdata_final)
        y = np.append(y, ydata_final)
        
    plt.plot(x, y, color="red", linewidth=0.1)
    plt.imshow(mask_dilated, extent=extent)
    plt.rcParams["figure.figsize"] = 12, 8
    #plt.colorbar(fraction=0.036, pad=0.04)
    plt.show()

# %%
import time

start = time.time()
CCA_visualization(specificday_mur_aug[:5], days_mur_aug)
end = time.time()
print('Time {} secs'.format(end-start))
# Out:
# /tmp/ipykernel_357230/3445070762.py:164: UserWarning: No contour levels were found within the data range.
#   c = plt.contour(X, Y, w, [thresValue])     #Create and store a set of contour lines or filled regions.
# /tmp/ipykernel_357230/3445070762.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   popBMean = popBSum/popBCount
# Time 370.68623447418213 secs

# %% [markdown]
# Quando testo para 1 imagem o tempo que demora é 44.4 s (44.4 * 5 = 220s). Á medida que aumenta o nr de imagens, o tempo de computação aumenta não linearmente (ou seja vai demorando mais, quantas mais imagens tiverem de ser processadas

# %% [markdown]
# ##### CProfile -> it hooks into the virtual machine to measure the time taken to run certain functions

# %%
import cProfile

cProfile.run('CCA_visualization(specificday_mur_aug[:1], days_mur_aug)')
# Out:
# /tmp/ipykernel_357230/3445070762.py:164: UserWarning: No contour levels were found within the data range.
#   c = plt.contour(X, Y, w, [thresValue])     #Create and store a set of contour lines or filled regions.
# /tmp/ipykernel_357230/3445070762.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   popBMean = popBSum/popBCount
#          18643009 function calls (18356087 primitive calls) in 45.958 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002   45.958   45.958 2193992244.py:1(CCA_visualization)
#     20400    4.656    0.000   24.641    0.001 3445070762.py:1(getFrontInWindow)
#      1658    0.000    0.000    0.000    0.000 3445070762.py:171(<listcomp>)
#      1657    0.002    0.000    0.002    0.000 3445070762.py:179(<listcomp>)
#         1    0.241    0.241   44.291   44.291 599911213.py:1(CCA_SIED)
#      8322    0.003    0.000    0.031    0.000 <__array_function__ internals>:2(all)
#     70339    0.025    0.000    0.250    0.000 <__array_function__ internals>:2(amax)
#     70330    0.026    0.000    0.285    0.000 <__array_function__ internals>:2(amin)
#     47236    0.021    0.000    0.309    0.000 <__array_function__ internals>:2(any)
#      6768    0.003    0.000    0.059    0.000 <__array_function__ internals>:2(append)
#       168    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(around)
#      3332    0.002    0.000    0.010    0.000 <__array_function__ internals>:2(atleast_1d)
#     16423    0.006    0.000    0.058    0.000 <__array_function__ internals>:2(atleast_2d)
#         4    0.000    0.000    0.009    0.002 <__array_function__ internals>:2(bincount)
#      1763    0.002    0.000    0.042    0.000 <__array_function__ internals>:2(broadcast_arrays)
#      1679    0.001    0.000    0.003    0.000 <__array_function__ internals>:2(can_cast)
#      3376    0.003    0.000    0.069    0.000 <__array_function__ internals>:2(clip)
#       103    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(column_stack)
#     46349    0.020    0.000    4.547    0.000 <__array_function__ internals>:2(concatenate)
#       275    0.000    0.000    0.004    0.000 <__array_function__ internals>:2(copyto)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(cumsum)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(delete)
#     16427    0.007    0.000    0.091    0.000 <__array_function__ internals>:2(diff)
#     18905    0.007    0.000    0.026    0.000 <__array_function__ internals>:2(dot)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(flipud)
#     16403    0.007    0.000    0.990    0.000 <__array_function__ internals>:2(histogram)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(hstack)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(isclose)
#      3318    0.002    0.000    0.089    0.000 <__array_function__ internals>:2(linspace)
#     16403    0.008    0.000    0.169    0.000 <__array_function__ internals>:2(mean)
#      1660    0.001    0.000    0.065    0.000 <__array_function__ internals>:2(meshgrid)
#      9958    0.005    0.000    0.018    0.000 <__array_function__ internals>:2(min_scalar_type)
#     16404    0.006    0.000    0.115    0.000 <__array_function__ internals>:2(nanmax)
#     16404    0.008    0.000    0.150    0.000 <__array_function__ internals>:2(nanmin)
#     42876    0.015    0.000    0.048    0.000 <__array_function__ internals>:2(ndim)
#        58    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(nonzero)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ones_like)
#        18    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#        56    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ptp)
#        12    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(putmask)
#      6768    0.003    0.000    0.021    0.000 <__array_function__ internals>:2(ravel)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(repeat)
#      3321    0.002    0.000    0.007    0.000 <__array_function__ internals>:2(result_type)
#       168    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(round_)
#      4138    0.002    0.000    0.008    0.000 <__array_function__ internals>:2(shape)
#     23037    0.011    0.000    0.825    0.000 <__array_function__ internals>:2(sort)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(tile)
#         6    0.000    0.000    0.118    0.020 <__array_function__ internals>:2(unique)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(unravel_index)
#     16423    0.007    0.000    0.131    0.000 <__array_function__ internals>:2(vstack)
#         9    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(where)
#         2    0.000    0.000    0.002    0.001 <__array_function__ internals>:2(zeros_like)
#      1729    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#        29    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:389(parent)
#         1    0.000    0.000   45.958   45.958 <string>:1(<module>)
#      2133    0.001    0.000    0.002    0.000 <string>:1(__new__)
#         4    0.000    0.000    0.000    0.000 __init__.py:101(get_op_result_name)
#      3336    0.002    0.000    0.002    0.000 __init__.py:118(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1294(get_backend)
#       137    0.000    0.000    0.000    0.000 __init__.py:1296(is_math_text)
#      3830    0.002    0.000    0.005    0.000 __init__.py:1309(_to_unmasked_float_array)
#         2    0.000    0.000    0.000    0.000 __init__.py:1312(is_interactive)
#         2    0.000    0.000    0.000    0.000 __init__.py:1320(_check_1d)
#        11    0.000    0.000    0.000    0.000 __init__.py:138(connect)
#      1659    0.004    0.000    8.970    0.005 __init__.py:1562(inner)
#         2    0.000    0.000    0.000    0.000 __init__.py:157(_remove_proxy)
#       101    0.000    0.000    0.000    0.000 __init__.py:1598(<lambda>)
#     19904    0.011    0.000    0.030    0.000 __init__.py:1633(safe_first_element)
#      6633    0.002    0.000    0.007    0.000 __init__.py:1655(sanitize_sequence)
#        71    0.001    0.000    0.001    0.000 __init__.py:1663(normalize_kwargs)
#         1    0.000    0.000    0.000    0.000 __init__.py:170(disconnect)
#        71    0.000    0.000    0.000    0.000 __init__.py:1760(<listcomp>)
#        71    0.000    0.000    0.000    0.000 __init__.py:1765(<listcomp>)
#         4    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#      9955    0.008    0.000    0.010    0.000 __init__.py:185(process)
#      6759    0.001    0.000    0.002    0.000 __init__.py:1850(_str_equal)
#      6729    0.002    0.000    0.003    0.000 __init__.py:1860(_str_lower_equal)
#        58    0.000    0.000    0.000    0.000 __init__.py:1891(method)
#         1    0.000    0.000    0.000    0.000 __init__.py:19(get_projection_class)
#      4272    0.004    0.000    0.009    0.000 __init__.py:1956(_setattr_cm)
#      2136    0.001    0.000    0.001    0.000 __init__.py:1961(<listcomp>)
#       411    0.002    0.000    0.008    0.000 __init__.py:1974(_warn_external)
#         1    0.000    0.000    0.000    0.000 __init__.py:1997(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:2009(add)
#      5158    0.012    0.000    0.017    0.000 __init__.py:2096(_check_isinstance)
#     10316    0.001    0.000    0.001    0.000 __init__.py:2111(<genexpr>)
#      5158    0.002    0.000    0.002    0.000 __init__.py:2113(type_name)
#      9635    0.009    0.000    0.010    0.000 __init__.py:2131(_check_in_list)
#      1660    0.000    0.000    0.000    0.000 __init__.py:223(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:359(to_filehandle)
#         2    0.000    0.000    0.000    0.000 __init__.py:415(open_file_cm)
#         1    0.000    0.000    0.000    0.000 __init__.py:44(get_projection_class)
#         4    0.000    0.000    0.000    0.000 __init__.py:448(_construct_result)
#         3    0.000    0.000    0.000    0.000 __init__.py:51(__init__)
#         4    0.000    0.000    0.002    0.001 __init__.py:518(wrapper)
#        24    0.000    0.000    0.000    0.000 __init__.py:557(__setitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:573(__init__)
#         7    0.000    0.000    0.000    0.000 __init__.py:60(__hash__)
#         2    0.000    0.000    0.000    0.000 __init__.py:601(push)
#         3    0.000    0.000    0.000    0.000 __init__.py:626(clear)
#         1    0.000    0.000    0.000    0.000 __init__.py:631(bubble)
#         1    0.000    0.000    0.000    0.000 __init__.py:705(safe_masked_invalid)
#         1    0.000    0.000    0.000    0.000 __init__.py:784(__setitem__)
#     48695    0.015    0.000    0.021    0.000 __init__.py:815(__getitem__)
#         2    0.000    0.000    0.000    0.000 __init__.py:827(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:828(<dictcomp>)
#         5    0.000    0.000    0.000    0.000 __init__.py:830(__contains__)
#     56919    0.021    0.000    0.027    0.000 __init__.py:833(clean)
#     56919    0.006    0.000    0.006    0.000 __init__.py:836(<listcomp>)
#     56917    0.049    0.000    0.091    0.000 __init__.py:882(get_siblings)
#     56917    0.010    0.000    0.010    0.000 __init__.py:886(<listcomp>)
#         5    0.000    0.000    0.001    0.000 _asarray.py:139(ascontiguousarray)
# 91345/91337    0.019    0.000    0.108    0.000 _asarray.py:14(asarray)
#         4    0.000    0.000    0.000    0.000 _asarray.py:221(require)
#         4    0.000    0.000    0.000    0.000 _asarray.py:298(<setcomp>)
#    138592    0.026    0.000    0.091    0.000 _asarray.py:86(asanyarray)
#         1    0.000    0.000    0.001    0.001 _axes.py:1414(plot)
#         1    0.000    0.000    0.002    0.002 _axes.py:5432(imshow)
#      1658    0.005    0.000    8.956    0.005 _axes.py:6334(contour)
#         1    0.000    0.000    0.000    0.000 _base.py:1116(_set_title_offset_trans)
#         8    0.000    0.000    0.000    0.000 _base.py:1202(get_aspect)
#         3    0.000    0.000    0.000    0.000 _base.py:1205(set_aspect)
#         3    0.000    0.000    0.000    0.000 _base.py:1287(set_adjustable)
#         2    0.000    0.000    0.000    0.000 _base.py:129(__init__)
#         5    0.000    0.000    0.000    0.000 _base.py:1336(get_anchor)
#         5    0.000    0.000    0.000    0.000 _base.py:1405(get_data_ratio)
#         2    0.000    0.000    0.000    0.000 _base.py:142(set_prop_cycle)
#         7    0.000    0.000    0.001    0.000 _base.py:1436(apply_aspect)
#         2    0.000    0.000    0.000    0.000 _base.py:153(__call__)
#      1659    0.019    0.000    0.019    0.000 _base.py:1728(_sci)
#      1658    0.004    0.000    0.152    0.000 _base.py:1803(add_collection)
#         1    0.000    0.000    0.000    0.000 _base.py:1826(add_image)
#         1    0.000    0.000    0.000    0.000 _base.py:1842(add_line)
#         1    0.000    0.000    0.000    0.000 _base.py:1868(_update_line_limits)
#      1659    0.003    0.000    0.028    0.000 _base.py:2009(update_datalim)
#      8293    0.006    0.000    0.112    0.000 _base.py:2045(_process_unit_info)
#     16586    0.010    0.000    0.105    0.000 _base.py:2048(_process_single_axis)
#      3315    0.001    0.000    0.001    0.000 _base.py:2133(use_sticky_edges)
#         1    0.000    0.000    0.000    0.000 _base.py:224(_getdefaults)
#         2    0.000    0.000    0.000    0.000 _base.py:232(<genexpr>)
# 3315/1658    0.050    0.000    7.055    0.004 _base.py:2332(autoscale_view)
#      3315    0.262    0.000    0.510    0.000 _base.py:2382(<listcomp>)
#      3315    0.261    0.000    0.493    0.000 _base.py:2388(<listcomp>)
# 6630/3316    0.102    0.000    4.095    0.001 _base.py:2398(handle_single_axis)
#      6630    0.001    0.000    0.001    0.000 _base.py:2405(<listcomp>)
#      6630    0.033    0.000    0.061    0.000 _base.py:2407(<listcomp>)
#      6630    0.012    0.000    0.030    0.000 _base.py:2411(<listcomp>)
#      6630    0.008    0.000    0.021    0.000 _base.py:2414(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _base.py:242(_setdefaults)
#     13260    0.003    0.000    0.004    0.000 _base.py:2432(tol)
#      9954    0.002    0.000    0.002    0.000 _base.py:2470(_get_axis_list)
#         6    0.000    0.000    0.001    0.000 _base.py:2491(_update_title_position)
#         1    0.000    0.000    0.000    0.000 _base.py:251(_makeline)
#        24    0.000    0.000    0.000    0.000 _base.py:2548(<genexpr>)
#         2    0.000    0.000    0.375    0.187 _base.py:2555(draw)
#         1    0.000    0.000    0.000    0.000 _base.py:2691(set_axisbelow)
#         2    0.000    0.000    0.003    0.001 _base.py:2727(grid)
#         2    0.000    0.000    0.001    0.000 _base.py:2884(tick_params)
#         1    0.000    0.000    0.000    0.000 _base.py:2971(set_axis_on)
#      3315    0.002    0.000    0.029    0.000 _base.py:2994(xaxis_inverted)
# 3320/1663    0.002    0.000    3.520    0.002 _base.py:3008(get_xbound)
# 3315/1658    0.005    0.000    3.602    0.002 _base.py:3024(set_xbound)
# 3320/1663    0.006    0.000    3.519    0.002 _base.py:3064(get_xlim)
#     13268    0.024    0.000    0.070    0.000 _base.py:3087(_validate_converted_limits)
#         1    0.000    0.000    0.000    0.000 _base.py:310(_plot_args)
#      3317    0.019    0.000    0.154    0.000 _base.py:3104(set_xlim)
#         3    0.000    0.000    0.000    0.000 _base.py:321(<genexpr>)
#      6632    0.003    0.000    0.005    0.000 _base.py:3241(get_xscale)
#      3315    0.002    0.000    0.027    0.000 _base.py:3405(yaxis_inverted)
#      3320    0.002    0.000    0.030    0.000 _base.py:3419(get_ybound)
#      3315    0.005    0.000    0.204    0.000 _base.py:3435(set_ybound)
#      3320    0.005    0.000    0.028    0.000 _base.py:3475(get_ylim)
#      3317    0.017    0.000    0.143    0.000 _base.py:3498(set_ylim)
#         1    0.000    0.000    0.000    0.000 _base.py:363(<listcomp>)
#      6632    0.002    0.000    0.004    0.000 _base.py:3635(get_yscale)
#         1    0.000    0.000    0.008    0.008 _base.py:378(__init__)
#         1    0.000    0.000    0.000    0.000 _base.py:3884(set_navigate)
#         1    0.000    0.000    0.000    0.000 _base.py:3900(set_navigate_mode)
#      6637    0.027    0.000    0.029    0.000 _base.py:4215(get_children)
#         3    0.000    0.000    0.002    0.001 _base.py:4247(get_default_bbox_extra_artists)
#         3    0.001    0.000    0.002    0.001 _base.py:4267(<listcomp>)
#         2    0.016    0.008    0.674    0.337 _base.py:4270(get_tightbbox)
#         2    0.001    0.000    0.002    0.001 _base.py:4367(<listcomp>)
#        22    0.000    0.000    0.000    0.000 _base.py:535(get_window_extent)
#         1    0.000    0.000    0.001    0.001 _base.py:553(_init_axis)
#         1    0.000    0.000    0.000    0.000 _base.py:563(set_figure)
# 13518/6890    0.021    0.000    3.540    0.001 _base.py:583(_unstale_viewLim)
#     27036    0.004    0.000    0.004    0.000 _base.py:586(<genexpr>)
#     27036    0.003    0.000    0.003    0.000 _base.py:588(<genexpr>)
# 13516/6888    0.005    0.000    3.542    0.001 _base.py:597(viewLim)
#      1659    0.001    0.000    0.001    0.000 _base.py:604(_request_autoscale_view)
#         1    0.000    0.000    0.000    0.000 _base.py:612(_set_lim_and_transforms)
#   353/195    0.000    0.000    0.001    0.000 _base.py:648(get_xaxis_transform)
#        39    0.000    0.000    0.001    0.000 _base.py:672(get_xaxis_text1_transform)
#        39    0.000    0.000    0.000    0.000 _base.py:698(get_xaxis_text2_transform)
#   335/185    0.000    0.000    0.001    0.000 _base.py:724(get_yaxis_transform)
#        37    0.000    0.000    0.001    0.000 _base.py:748(get_yaxis_text1_transform)
#        37    0.000    0.000    0.000    0.000 _base.py:774(get_yaxis_text2_transform)
#         2    0.000    0.000    0.000    0.000 _base.py:800(_update_transScale)
#       6/5    0.000    0.000    0.000    0.000 _base.py:810(get_position)
#         7    0.000    0.000    0.000    0.000 _base.py:859(_set_position)
#         3    0.000    0.000    0.000    0.000 _base.py:886(set_axes_locator)
#         8    0.000    0.000    0.000    0.000 _base.py:897(get_axes_locator)
#      1663    0.003    0.000    0.006    0.000 _base.py:903(_set_artist_props)
#         1    0.000    0.000    0.000    0.000 _base.py:913(_gen_axes_patch)
#         1    0.000    0.000    0.000    0.000 _base.py:930(_gen_axes_spines)
#         5    0.000    0.000    0.000    0.000 _base.py:945(<genexpr>)
#         1    0.000    0.000    0.006    0.006 _base.py:948(cla)
#         2    0.000    0.000    0.003    0.002 _decorators.py:225(wrapper)
#       196    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#       196    0.000    0.000    0.001    0.000 _dtype.py:307(_name_includes_bit_suffix)
#       196    0.000    0.000    0.001    0.000 _dtype.py:321(_name_get)
#        31    0.000    0.000    0.000    0.000 _dtype.py:34(__str__)
#      3376    0.007    0.000    0.056    0.000 _methods.py:106(_clip)
#     16403    0.066    0.000    0.134    0.000 _methods.py:143(_mean)
#        56    0.000    0.000    0.000    0.000 _methods.py:245(_ptp)
#     10238    0.002    0.000    0.048    0.000 _methods.py:37(_amax)
#     10066    0.003    0.000    0.054    0.000 _methods.py:41(_amin)
#        66    0.000    0.000    0.009    0.000 _methods.py:45(_sum)
#     50294    0.011    0.000    0.070    0.000 _methods.py:53(_any)
#     28198    0.006    0.000    0.058    0.000 _methods.py:56(_all)
#     16403    0.014    0.000    0.019    0.000 _methods.py:59(_count_reduce_items)
#      6752    0.017    0.000    0.034    0.000 _methods.py:72(_clip_dep_is_scalar_nan)
#      6752    0.002    0.000    0.002    0.000 _methods.py:82(_clip_dep_is_byte_swapped)
#      3376    0.012    0.000    0.012    0.000 _methods.py:87(_clip_dep_invoke_with_casting)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:109(set_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:115(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:29(get_fig_manager)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:65(destroy_all)
#         2    0.000    0.000    0.000    0.000 _pylab_helpers.py:85(get_all_fig_managers)
#      3320    0.002    0.000    0.002    0.000 _pylab_helpers.py:99(get_active)
#         1    0.000    0.000    0.000    0.000 _subplots.py:117(get_subplotspec)
#         1    0.000    0.000    0.000    0.000 _subplots.py:129(update_params)
#         1    0.000    0.000    0.008    0.008 _subplots.py:18(__init__)
#     13390    0.014    0.000    0.015    0.000 _ufunc_config.py:132(geterr)
#     13390    0.018    0.000    0.042    0.000 _ufunc_config.py:32(seterr)
#      6695    0.002    0.000    0.002    0.000 _ufunc_config.py:429(__init__)
#      6695    0.005    0.000    0.029    0.000 _ufunc_config.py:433(__enter__)
#      6695    0.004    0.000    0.022    0.000 _ufunc_config.py:438(__exit__)
#        18    0.000    0.000    0.000    0.000 _validators.py:207(validate_bool_kwarg)
#         2    0.000    0.000    0.000    0.000 _validators.py:217(validate_axis_style_args)
#        24    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#     58861    0.010    0.000    0.022    0.000 abc.py:96(__instancecheck__)
#        53    0.000    0.000    0.001    0.000 algorithms.py:1436(_get_take_nd_function)
#        53    0.000    0.000    0.051    0.001 algorithms.py:1565(take_nd)
#         4    0.000    0.000    0.001    0.000 algorithms.py:171(_reconstruct_data)
#         4    0.000    0.000    0.007    0.002 algorithms.py:1940(safe_sort)
#         4    0.000    0.000    0.000    0.000 algorithms.py:205(_ensure_arraylike)
#         4    0.000    0.000    0.000    0.000 algorithms.py:247(_get_values_for_rank)
#         4    0.000    0.000    0.000    0.000 algorithms.py:255(_get_data_algo)
#         4    0.000    0.000    0.000    0.000 algorithms.py:264(_check_object_for_strings)
#         4    0.000    0.000    0.029    0.007 algorithms.py:456(_factorize_array)
#         4    0.000    0.000    0.037    0.009 algorithms.py:585(factorize)
#         8    0.000    0.000    0.000    0.000 algorithms.py:64(_ensure_data)
#         4    0.002    0.000    0.002    0.000 array_ops.py:202(comparison_op)
#         6    0.000    0.000    0.000    0.000 arraysetops.py:136(_unpack_tuple)
#         6    0.000    0.000    0.000    0.000 arraysetops.py:144(_unique_dispatcher)
#         6    0.000    0.000    0.118    0.020 arraysetops.py:149(unique)
#         6    0.004    0.001    0.118    0.020 arraysetops.py:309(_unique1d)
#      2119    0.002    0.000    0.052    0.000 artist.py:1006(<listcomp>)
#      1660    0.000    0.000    0.000    0.000 artist.py:1013(get_label)
#      1661    0.001    0.000    0.002    0.000 artist.py:1017(set_label)
#         2    0.000    0.000    0.000    0.000 artist.py:1033(get_zorder)
#      1816    0.001    0.000    0.003    0.000 artist.py:1037(set_zorder)
#   5571100    0.450    0.000    0.450    0.000 artist.py:1052(sticky_edges)
#        60    0.000    0.000    0.000    0.000 artist.py:1074(update_from)
#        70    0.000    0.000    0.001    0.000 artist.py:1095(set)
#      1663    0.000    0.000    0.000    0.000 artist.py:1201(mouseover)
#      3316    0.002    0.000    0.007    0.000 artist.py:163(have_units)
#      9948    0.002    0.000    0.003    0.000 artist.py:166(<genexpr>)
#     12187    0.005    0.000    0.030    0.000 artist.py:168(convert_xunits)
#     12185    0.005    0.000    0.025    0.000 artist.py:180(convert_yunits)
#     54310    0.006    0.000    0.006    0.000 artist.py:192(axes)
#      3879    0.001    0.000    0.001    0.000 artist.py:197(axes)
# 72245/52032    0.031    0.000    0.048    0.000 artist.py:217(stale)
#      3340    0.002    0.000    0.003    0.000 artist.py:250(_get_clipping_extent_bbox)
#      5004    0.009    0.000    0.477    0.000 artist.py:267(get_tightbbox)
#    3506/2    0.004    0.000    0.376    0.188 artist.py:30(draw_wrapper)
#     13454    0.004    0.000    0.005    0.000 artist.py:336(pchanged)
#      1663    0.000    0.000    0.000    0.000 artist.py:350(is_transform_set)
#      2057    0.001    0.000    0.003    0.000 artist.py:358(set_transform)
#     10283    0.003    0.000    0.004    0.000 artist.py:371(get_transform)
#      6030    0.004    0.000    0.015    0.000 artist.py:49(_stale_axes_callback)
#         2    0.000    0.000    0.000    0.000 artist.py:566(get_url)
#         1    0.000    0.000    0.000    0.000 artist.py:570(set_url)
#      3412    0.000    0.000    0.000    0.000 artist.py:580(get_gid)
#      3330    0.001    0.000    0.002    0.000 artist.py:594(get_snap)
#      3354    0.000    0.000    0.000    0.000 artist.py:633(get_sketch_params)
#      3378    0.000    0.000    0.000    0.000 artist.py:688(get_path_effects)
#         5    0.000    0.000    0.000    0.000 artist.py:691(get_figure)
#      2132    0.002    0.000    0.003    0.000 artist.py:695(set_figure)
#         3    0.000    0.000    0.000    0.000 artist.py:719(set_clip_box)
#      1674    0.007    0.000    0.141    0.000 artist.py:731(set_clip_path)
#      2133    0.007    0.000    0.011    0.000 artist.py:74(__init__)
#        26    0.000    0.000    0.000    0.000 artist.py:793(get_alpha)
#      9309    0.001    0.000    0.001    0.000 artist.py:800(get_visible)
#     72247    0.007    0.000    0.007    0.000 artist.py:804(get_animated)
#      5012    0.000    0.000    0.000    0.000 artist.py:808(get_in_layout)
#      8344    0.001    0.000    0.001    0.000 artist.py:819(get_clip_on)
#      8346    0.001    0.000    0.001    0.000 artist.py:823(get_clip_box)
#     10004    0.001    0.000    0.001    0.000 artist.py:827(get_clip_path)
#      3380    0.002    0.000    0.014    0.000 artist.py:858(_set_gc_clip)
#      7012    0.001    0.000    0.001    0.000 artist.py:868(get_rasterized)
#      7012    0.001    0.000    0.001    0.000 artist.py:888(get_agg_filter)
#      1734    0.001    0.000    0.002    0.000 artist.py:923(set_alpha)
#       429    0.000    0.000    0.000    0.000 artist.py:937(set_visible)
#         1    0.000    0.000    0.000    0.000 artist.py:961(set_in_layout)
#      2119    0.006    0.000    0.075    0.000 artist.py:974(update)
#      3546    0.004    0.000    0.050    0.000 artist.py:978(_update_property)
#      6630    0.008    0.000    0.052    0.000 axis.py:1010(get_inverted)
#         4    0.000    0.000    0.000    0.000 axis.py:1048(_set_artist_props)
#        28    0.001    0.000    0.046    0.002 axis.py:1098(_update_ticks)
#        28    0.000    0.000    0.022    0.001 axis.py:1171(_get_tick_bboxes)
#        28    0.000    0.000    0.022    0.001 axis.py:1173(<listcomp>)
#        28    0.000    0.000    0.000    0.000 axis.py:1175(<listcomp>)
#        10    0.000    0.000    0.042    0.004 axis.py:1178(get_tightbbox)
#        30    0.000    0.000    0.000    0.000 axis.py:1198(<genexpr>)
#        10    0.000    0.000    0.000    0.000 axis.py:1204(<listcomp>)
#         4    0.000    0.000    0.040    0.010 axis.py:1219(draw)
#         2    0.000    0.000    0.008    0.004 axis.py:1274(get_majorticklabels)
#         2    0.000    0.000    0.000    0.000 axis.py:1277(<listcomp>)
#         2    0.000    0.000    0.000    0.000 axis.py:1278(<listcomp>)
#         2    0.000    0.000    0.008    0.004 axis.py:1288(get_ticklabels)
#        30    0.000    0.000    0.019    0.001 axis.py:1346(get_majorticklocs)
#        28    0.000    0.000    0.017    0.001 axis.py:1350(get_minorticklocs)
#        28    0.000    0.000    0.000    0.000 axis.py:1363(<listcomp>)
#        12    0.000    0.000    0.001    0.000 axis.py:1398(_copy_tick_props)
#     13264    0.004    0.000    0.006    0.000 axis.py:1412(get_major_locator)
#        30    0.000    0.000    0.008    0.000 axis.py:1428(get_major_ticks)
#        28    0.000    0.000    0.000    0.000 axis.py:1442(get_minor_ticks)
#         4    0.000    0.000    0.003    0.001 axis.py:1456(grid)
#         4    0.000    0.000    0.000    0.000 axis.py:1486(<dictcomp>)
#      9952    0.006    0.000    0.093    0.000 axis.py:1504(update_units)
#        76    0.000    0.000    0.000    0.000 axis.py:153(<dictcomp>)
#     16582    0.003    0.000    0.003    0.000 axis.py:1559(have_units)
#     16652    0.006    0.000    0.036    0.000 axis.py:1562(convert_units)
#        12    0.000    0.000    0.000    0.000 axis.py:1579(set_units)
#        16    0.000    0.000    0.000    0.000 axis.py:1620(set_major_formatter)
#        16    0.000    0.000    0.000    0.000 axis.py:1634(set_minor_formatter)
#        16    0.000    0.000    0.000    0.000 axis.py:1648(set_major_locator)
#        16    0.000    0.000    0.000    0.000 axis.py:1664(set_minor_locator)
#        18    0.000    0.000    0.000    0.000 axis.py:1828(_get_ticks_position)
#        54    0.000    0.000    0.000    0.000 axis.py:1844(<genexpr>)
#        18    0.000    0.000    0.000    0.000 axis.py:1865(get_label_position)
#      6856    0.004    0.000    0.046    0.000 axis.py:1891(getter)
#        39    0.000    0.000    0.020    0.001 axis.py:1938(_get_tick)
#         1    0.000    0.000    0.000    0.000 axis.py:1945(_get_label)
#         1    0.000    0.000    0.000    0.000 axis.py:1963(_get_offset_text)
#        76    0.000    0.000    0.000    0.000 axis.py:197(_set_labelrotation)
#         7    0.000    0.000    0.013    0.002 axis.py:1992(_get_tick_boxes_siblings)
#         7    0.000    0.000    0.015    0.002 axis.py:2011(_update_label_position)
#         7    0.000    0.000    0.001    0.000 axis.py:2054(_update_offset_text_position)
#        18    0.000    0.000    0.000    0.000 axis.py:2147(get_ticks_position)
#        76    0.000    0.000    0.000    0.000 axis.py:215(get_tick_padding)
#      3317    0.002    0.000    0.003    0.000 axis.py:2160(get_minpos)
#        29    0.000    0.000    0.015    0.001 axis.py:2187(get_tick_space)
#        37    0.000    0.000    0.017    0.000 axis.py:2225(_get_tick)
#         1    0.000    0.000    0.000    0.000 axis.py:2232(_get_label)
#         1    0.000    0.000    0.000    0.000 axis.py:2252(_get_offset_text)
#         7    0.000    0.000    0.012    0.002 axis.py:2284(_get_tick_boxes_siblings)
#         6    0.000    0.000    0.001    0.000 axis.py:229(set_clip_path)
#         7    0.000    0.000    0.014    0.002 axis.py:2303(_update_label_position)
#         7    0.000    0.000    0.000    0.000 axis.py:2345(_update_offset_text_position)
#      3317    0.002    0.000    0.003    0.000 axis.py:2460(get_minpos)
#        29    0.000    0.000    0.014    0.000 axis.py:2487(get_tick_space)
#       224    0.000    0.000    0.000    0.000 axis.py:285(get_loc)
#        24    0.000    0.000    0.006    0.000 axis.py:289(draw)
#       224    0.000    0.000    0.001    0.000 axis.py:301(set_label1)
#       224    0.000    0.000    0.001    0.000 axis.py:314(set_label2)
#       380    0.000    0.000    0.001    0.000 axis.py:325(_set_artist_props)
#        14    0.000    0.000    0.001    0.000 axis.py:334(_apply_params)
#        70    0.000    0.000    0.000    0.000 axis.py:342(<genexpr>)
#        14    0.000    0.000    0.000    0.000 axis.py:361(<dictcomp>)
#        14    0.000    0.000    0.000    0.000 axis.py:372(<dictcomp>)
#        14    0.000    0.000    0.000    0.000 axis.py:383(<dictcomp>)
#        39    0.000    0.000    0.001    0.000 axis.py:407(_get_text1_transform)
#        39    0.000    0.000    0.000    0.000 axis.py:410(_get_text2_transform)
#        39    0.000    0.000    0.000    0.000 axis.py:413(apply_tickdir)
#        39    0.000    0.000    0.003    0.000 axis.py:427(_get_text1)
#        39    0.000    0.000    0.002    0.000 axis.py:444(_get_text2)
#        39    0.000    0.000    0.005    0.000 axis.py:459(_get_tick1line)
#        39    0.000    0.000    0.004    0.000 axis.py:470(_get_tick2line)
#        39    0.000    0.000    0.005    0.000 axis.py:485(_get_gridline)
#       165    0.000    0.000    0.001    0.000 axis.py:501(update_position)
#        37    0.000    0.000    0.001    0.000 axis.py:523(_get_text1_transform)
#        37    0.000    0.000    0.000    0.000 axis.py:526(_get_text2_transform)
#        37    0.000    0.000    0.000    0.000 axis.py:529(apply_tickdir)
#        37    0.000    0.000    0.002    0.000 axis.py:544(_get_text1)
#        37    0.000    0.000    0.002    0.000 axis.py:559(_get_text2)
#        76    0.001    0.000    0.037    0.000 axis.py:56(__init__)
#        37    0.000    0.000    0.004    0.000 axis.py:574(_get_tick1line)
#        37    0.000    0.000    0.003    0.000 axis.py:589(_get_tick2line)
#        37    0.000    0.000    0.004    0.000 axis.py:603(_get_gridline)
#       135    0.000    0.000    0.001    0.000 axis.py:618(update_position)
#         4    0.000    0.000    0.000    0.000 axis.py:645(__init__)
#     13350    0.002    0.000    0.002    0.000 axis.py:649(locator)
#        32    0.000    0.000    0.000    0.000 axis.py:653(locator)
#       188    0.000    0.000    0.000    0.000 axis.py:662(formatter)
#        32    0.000    0.000    0.000    0.000 axis.py:666(formatter)
#       6/4    0.000    0.000    0.003    0.001 axis.py:687(__get__)
#         2    0.000    0.000    0.001    0.000 axis.py:744(__init__)
#        28    0.000    0.000    0.000    0.000 axis.py:788(get_remove_overlapping_locs)
#      6896    0.003    0.000    0.013    0.000 axis.py:819(get_transform)
#     13264    0.003    0.000    0.003    0.000 axis.py:822(get_scale)
#        16    0.000    0.000    0.001    0.000 axis.py:825(_set_scale)
#      6634    0.004    0.000    0.011    0.000 axis.py:834(limit_range_for_scale)
#        12    0.000    0.000    0.001    0.000 axis.py:841(cla)
#        16    0.000    0.000    0.000    0.000 axis.py:864(reset_ticks)
#         8    0.000    0.000    0.003    0.000 axis.py:884(set_tick_params)
#         8    0.000    0.000    0.000    0.000 axis.py:922(_translate_tick_kw)
#         2    0.000    0.000    0.002    0.001 axis.py:967(set_clip_path)
#         2    0.000    0.000    0.000    0.000 backend_agg.py:108(_update_methods)
#         7    0.000    0.000    0.002    0.000 backend_agg.py:125(draw_path)
#        12    0.000    0.000    0.001    0.000 backend_agg.py:170(draw_text)
#        48    0.000    0.000    0.014    0.000 backend_agg.py:196(get_text_width_height_descent)
#        24    0.000    0.000    0.000    0.000 backend_agg.py:239(get_canvas_width_height)
#        60    0.000    0.000    0.001    0.000 backend_agg.py:243(_get_agg_font)
#        48    0.000    0.000    0.000    0.000 backend_agg.py:256(points_to_pixels)
#         4    0.000    0.000    0.000    0.000 backend_agg.py:272(option_image_nocomposite)
#         2    0.000    0.000    0.226    0.113 backend_agg.py:384(draw)
#         3    0.000    0.000    0.001    0.000 backend_agg.py:398(get_renderer)
#         2    0.000    0.000    0.245    0.123 backend_agg.py:454(print_png)
#        60    0.000    0.000    0.000    0.000 backend_agg.py:55(get_hinting_flag)
#         2    0.000    0.000    0.001    0.000 backend_agg.py:86(__init__)
#      1690    0.000    0.000    0.000    0.000 backend_bases.py:1001(get_hatch_color)
#      1690    0.000    0.000    0.000    0.000 backend_bases.py:1009(get_hatch_linewidth)
#      1690    0.000    0.000    0.000    0.000 backend_bases.py:1013(get_sketch_params)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1236(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1265(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:151(__init__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1541(_get_renderer)
#      1705    0.000    0.000    0.000    0.000 backend_bases.py:155(open_group)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1553(Done)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1556(_draw)
#      1705    0.000    0.000    0.000    0.000 backend_bases.py:162(close_group)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1635(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1687(is_saving)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1704(draw_event)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1929(draw)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1982(_get_output_canvas)
#         1    0.001    0.001    1.284    1.284 backend_bases.py:2001(print_figure)
#         7    0.000    0.000    0.000    0.000 backend_bases.py:2185(mpl_connect)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2240(mpl_disconnect)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2564(__init__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2582(notify_axes_change)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2597(destroy)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3351(new_figure_manager)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3360(new_figure_manager_given_figure)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:450(get_image_magnification)
#        24    0.000    0.000    0.000    0.000 backend_bases.py:637(flipy)
#      3380    0.001    0.000    0.015    0.000 backend_bases.py:656(new_gc)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:716(_draw_disabled)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:724(<dictcomp>)
#      5100    0.000    0.000    0.000    0.000 backend_bases.py:725(<lambda>)
#      3380    0.005    0.000    0.014    0.000 backend_bases.py:737(__init__)
#      3380    0.000    0.000    0.000    0.000 backend_bases.py:778(restore)
#      1690    0.000    0.000    0.000    0.000 backend_bases.py:807(get_clip_path)
#      1690    0.000    0.000    0.000    0.000 backend_bases.py:817(get_dashes)
#      1690    0.000    0.000    0.000    0.000 backend_bases.py:857(get_snap)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:868(set_alpha)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:885(set_antialiased)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:890(set_capstyle)
#      3320    0.000    0.000    0.000    0.000 backend_bases.py:895(set_clip_rectangle)
#      3380    0.002    0.000    0.011    0.000 backend_bases.py:901(set_clip_path)
#        14    0.000    0.000    0.000    0.000 backend_bases.py:912(set_dashes)
#       100    0.000    0.000    0.000    0.000 backend_bases.py:938(set_foreground)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:958(set_joinstyle)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:963(set_linewidth)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:967(set_url)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:971(set_gid)
#      3354    0.000    0.000    0.000    0.000 backend_bases.py:975(set_snap)
#      1690    0.000    0.000    0.000    0.000 backend_bases.py:990(get_hatch)
#      1690    0.000    0.000    0.001    0.000 backend_bases.py:994(get_hatch_path)
#         1    0.000    0.000    0.008    0.008 backend_inline.py:226(_fetch_figure_metadata)
#         1    0.000    0.000    1.293    1.293 backend_inline.py:23(show)
#         1    0.000    0.000    0.008    0.008 backend_inline.py:231(<listcomp>)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:242(_is_light)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:250(_is_transparent)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:59(draw_if_interactive)
#         1    0.000    0.000    0.000    0.000 base.py:1026(__iter__)
#        76    0.000    0.000    0.000    0.000 base.py:1182(name)
#         2    0.000    0.000    0.000    0.000 base.py:1197(_validate_names)
#         4    0.000    0.000    0.000    0.000 base.py:1217(_get_names)
#         2    0.000    0.000    0.000    0.000 base.py:1220(_set_names)
#         2    0.000    0.000    0.000    0.000 base.py:1250(set_names)
#         2    0.000    0.000    0.000    0.000 base.py:1329(rename)
#        12    0.000    0.000    0.000    0.000 base.py:1383(nlevels)
#         2    0.000    0.000    0.000    0.000 base.py:1484(droplevel)
#         4    0.000    0.000    0.000    0.000 base.py:1506(<genexpr>)
#      12/4    0.000    0.000    0.000    0.000 base.py:1581(is_monotonic)
#         8    0.000    0.000    0.000    0.000 base.py:1588(is_monotonic_increasing)
#         8    0.000    0.000    0.000    0.000 base.py:1656(is_unique)
#         8    0.000    0.000    0.000    0.000 base.py:1667(is_boolean)
#         4    0.000    0.000    0.000    0.000 base.py:1679(is_object)
#         2    0.000    0.000    0.000    0.000 base.py:1682(is_categorical)
#        10    0.000    0.000    0.000    0.000 base.py:1730(inferred_type)
#         4    0.000    0.000    0.000    0.000 base.py:1755(_isnan)
#         4    0.000    0.000    0.000    0.000 base.py:1775(hasnans)
#       280    0.000    0.000    0.000    0.000 base.py:194(construct_from_string)
#         2    0.000    0.000    0.004    0.002 base.py:203(_obj_with_exclusions)
#       322    0.000    0.000    0.001    0.000 base.py:247(is_dtype)
#         2    0.000    0.000    0.398    0.199 base.py:254(_try_aggregate_string_function)
#        18    0.000    0.000    0.000    0.000 base.py:2637(get_loc)
#         8    0.000    0.000    0.001    0.000 base.py:2706(get_indexer)
#     20/14    0.000    0.000    0.001    0.000 base.py:276(__new__)
#         2    0.000    0.000    0.398    0.199 base.py:285(_aggregate)
#         2    0.000    0.000    0.000    0.000 base.py:2967(_convert_listlike_indexer)
#         2    0.000    0.000    0.000    0.000 base.py:3004(_convert_arr_indexer)
#         2    0.000    0.000    0.000    0.000 base.py:3044(_convert_list_indexer)
#         2    0.000    0.000    0.000    0.000 base.py:3084(_can_reindex)
#         4    0.000    0.000    0.000    0.000 base.py:3101(reindex)
#       120    0.000    0.000    0.000    0.000 base.py:3639(values)
#        18    0.000    0.000    0.000    0.000 base.py:3671(_values)
#        16    0.000    0.000    0.000    0.000 base.py:3701(_internal_get_values)
#        24    0.000    0.000    0.000    0.000 base.py:3898(__contains__)
#         6    0.000    0.000    0.000    0.000 base.py:3912(__getitem__)
#         4    0.000    0.000    0.000    0.000 base.py:3950(_can_hold_identifiers_and_holds_name)
#        12    0.000    0.000    0.000    0.000 base.py:4047(equals)
#         2    0.000    0.000    0.000    0.000 base.py:4077(identical)
#         2    0.000    0.000    0.000    0.000 base.py:4489(get_indexer_for)
#         8    0.000    0.000    0.000    0.000 base.py:4506(_maybe_promote)
#        78    0.000    0.000    0.000    0.000 base.py:472(_simple_new)
#         2    0.000    0.000    0.000    0.000 base.py:4723(_maybe_cast_indexer)
#         2    0.000    0.000    0.000    0.000 base.py:4963(delete)
#         2    0.000    0.000    0.000    0.000 base.py:4993(drop)
#        64    0.000    0.000    0.000    0.000 base.py:505(_get_attributes_dict)
#        64    0.000    0.000    0.000    0.000 base.py:509(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 base.py:5237(shape)
#        64    0.000    0.000    0.001    0.000 base.py:526(_shallow_copy)
#       129    0.000    0.000    0.001    0.000 base.py:5294(ensure_index)
#         4    0.000    0.000    0.000    0.000 base.py:5361(_ensure_has_len)
#        45    0.000    0.000    0.000    0.000 base.py:5394(maybe_extract_name)
#         6    0.000    0.000    0.000    0.000 base.py:5410(_maybe_cast_with_dtype)
#         6    0.000    0.000    0.000    0.000 base.py:5464(_maybe_cast_data_without_dtype)
#        16    0.000    0.000    0.000    0.000 base.py:573(is_)
#        88    0.000    0.000    0.000    0.000 base.py:592(_reset_identity)
#        16    0.000    0.000    0.000    0.000 base.py:602(_engine)
#        18    0.000    0.000    0.000    0.000 base.py:609(<lambda>)
#        36    0.000    0.000    0.000    0.000 base.py:61(_reset_cache)
#       317    0.000    0.000    0.000    0.000 base.py:615(__len__)
#        28    0.000    0.000    0.000    0.000 base.py:638(dtype)
#         4    0.000    0.000    0.000    0.000 base.py:666(size)
#         4    0.000    0.000    0.000    0.000 base.py:741(to_numpy)
#        12    0.000    0.000    0.000    0.000 base.py:744(take)
#        12    0.000    0.000    0.000    0.000 base.py:766(_assert_take_fillable)
#        28    0.000    0.000    0.000    0.000 base.py:853(_ndarray_values)
#        54    0.000    0.000    0.000    0.000 blocks.py:118(__init__)
#        12    0.000    0.000    0.020    0.002 blocks.py:1277(take_nd)
#        54    0.000    0.000    0.000    0.000 blocks.py:129(_check_ndim)
#         4    0.000    0.000    0.000    0.000 blocks.py:187(is_categorical_astype)
#         4    0.000    0.000    0.000    0.000 blocks.py:202(external_values)
#        11    0.000    0.000    0.000    0.000 blocks.py:213(internal_values)
#         8    0.000    0.000    0.000    0.000 blocks.py:219(array_values)
#        11    0.000    0.000    0.000    0.000 blocks.py:225(get_values)
#        12    0.000    0.000    0.000    0.000 blocks.py:243(fill_value)
#       184    0.000    0.000    0.000    0.000 blocks.py:247(mgr_locs)
#        58    0.000    0.000    0.000    0.000 blocks.py:251(mgr_locs)
#         1    0.000    0.000    0.000    0.000 blocks.py:2597(__init__)
#        10    0.000    0.000    0.000    0.000 blocks.py:265(make_block)
#        26    0.000    0.000    0.000    0.000 blocks.py:275(make_block_same_class)
#        28    0.000    0.000    0.001    0.000 blocks.py:2987(get_block_type)
#        54    0.000    0.000    0.001    0.000 blocks.py:3033(make_block)
#        14    0.000    0.000    0.000    0.000 blocks.py:3059(_extend_blocks)
#         8    0.000    0.000    0.000    0.000 blocks.py:3078(_block_shape)
#        19    0.000    0.000    0.000    0.000 blocks.py:335(shape)
#        87    0.000    0.000    0.000    0.000 blocks.py:339(dtype)
#        31    0.000    0.000    0.000    0.000 blocks.py:343(ftype)
#         6    0.000    0.000    0.000    0.000 blocks.py:365(iget)
#         8    0.000    0.000    0.002    0.000 blocks.py:385(apply)
#         4    0.000    0.000    0.002    0.001 blocks.py:554(astype)
#         2    0.000    0.000    0.001    0.001 blocks.py:650(convert)
#         8    0.000    0.000    0.003    0.000 blocks.py:694(copy)
#        13    0.000    0.000    0.000    0.000 cast.py:1088(maybe_castable)
#         8    0.000    0.000    0.000    0.000 cast.py:1102(maybe_infer_to_datetimelike)
#         9    0.000    0.000    0.000    0.000 cast.py:1209(maybe_cast_to_datetime)
#         2    0.000    0.000    0.000    0.000 cast.py:1458(construct_1d_object_array_from_listlike)
#         9    0.000    0.000    0.000    0.000 cast.py:1483(construct_1d_ndarray_preserving_na)
#         2    0.000    0.000    0.002    0.001 cast.py:167(maybe_downcast_numeric)
#        26    0.000    0.000    0.001    0.000 cast.py:347(maybe_promote)
#        26    0.000    0.000    0.000    0.000 cast.py:503(_ensure_dtype_type)
#        28    0.000    0.000    0.003    0.000 cast.py:757(coerce_indexer_dtype)
#         4    0.000    0.000    0.000    0.000 categorical.py:312(__init__)
#         4    0.000    0.000    0.000    0.000 categorical.py:396(categories)
#         8    0.000    0.000    0.000    0.000 categorical.py:446(dtype)
#         4    0.000    0.000    0.000    0.000 categorical.py:592(from_codes)
#         8    0.000    0.000    0.000    0.000 categorical.py:662(_get_codes)
#      6634    0.007    0.000    0.071    0.000 cm.py:113(get_cmap)
#      3317    0.007    0.000    0.084    0.000 cm.py:148(__init__)
#      3318    0.011    0.000    0.667    0.000 cm.py:178(to_rgba)
#      1658    0.001    0.000    0.001    0.000 cm.py:248(set_array)
#         2    0.000    0.000    0.000    0.000 cm.py:258(get_array)
#      1659    0.002    0.000    0.348    0.000 cm.py:347(autoscale_None)
#      3317    0.004    0.000    0.008    0.000 cm.py:374(changed)
#      1658    0.008    0.000    0.301    0.000 collections.py:1253(__init__)
#      1658    0.003    0.000    0.016    0.000 collections.py:1361(set_segments)
#      1658    0.002    0.000    0.010    0.000 collections.py:1374(<listcomp>)
#      1658    0.001    0.000    0.053    0.000 collections.py:1410(set_color)
#      8290    0.001    0.000    0.001    0.000 collections.py:167(get_paths)
#      6632    0.001    0.000    0.001    0.000 collections.py:173(get_transforms)
#      8290    0.002    0.000    0.003    0.000 collections.py:176(get_offset_transform)
#      4974    0.012    0.000    0.212    0.000 collections.py:183(get_datalim)
#      4974    0.004    0.000    0.219    0.000 collections.py:248(get_window_extent)
#      3316    0.005    0.000    0.017    0.000 collections.py:253(_prepare_points)
#      3316    0.022    0.000    0.235    0.000 collections.py:290(draw)
#      1658    0.001    0.000    0.001    0.000 collections.py:375(set_pickradius)
#      1658    0.001    0.000    0.001    0.000 collections.py:422(set_urls)
#      1658    0.001    0.000    0.001    0.000 collections.py:434(set_hatch)
#      1658    0.002    0.000    0.003    0.000 collections.py:499(set_offset_position)
#      1658    0.003    0.000    0.020    0.000 collections.py:527(set_linewidth)
#      1658    0.003    0.000    0.015    0.000 collections.py:549(set_linestyle)
#      1658    0.001    0.000    0.002    0.000 collections.py:581(<listcomp>)
#      3316    0.005    0.000    0.012    0.000 collections.py:624(_bcast_lwls)
#      3316    0.002    0.000    0.005    0.000 collections.py:657(<listcomp>)
#      1658    0.002    0.000    0.010    0.000 collections.py:662(set_antialiased)
#      3316    0.004    0.000    0.013    0.000 collections.py:691(_set_facecolor)
#      1658    0.001    0.000    0.008    0.000 collections.py:704(set_facecolor)
#      6632    0.001    0.000    0.001    0.000 collections.py:719(get_facecolor)
#      6632    0.002    0.000    0.004    0.000 collections.py:722(get_edgecolor)
#      4974    0.021    0.000    0.112    0.000 collections.py:728(_set_edgecolor)
#      3316    0.002    0.000    0.084    0.000 collections.py:756(set_edgecolor)
# ...
#    611062    0.055    0.000    0.102    0.000 {built-in method builtins.getattr}
#     87158    0.011    0.000    0.014    0.000 {built-in method builtins.hasattr}
#  1014/702    0.000    0.000    0.001    0.000 {built-in method builtins.hash}
#    110964    0.008    0.000    0.008    0.000 {built-in method builtins.id}
#    720291    0.072    0.000    0.095    0.000 {built-in method builtins.isinstance}
#     69469    0.009    0.000    0.009    0.000 {built-in method builtins.issubclass}
#     55325    0.011    0.000    0.011    0.000 {built-in method builtins.iter}
# 169074/168643    0.018    0.000    0.018    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#     26856    0.011    0.000    0.011    0.000 {built-in method builtins.max}
#     13304    0.009    0.000    0.009    0.000 {built-in method builtins.min}
#     14451    0.003    0.000    0.012    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.round}
#      4304    0.001    0.000    0.004    0.000 {built-in method builtins.setattr}
#     10226    0.060    0.000    0.060    0.000 {built-in method builtins.sorted}
#   2190622    8.852    0.000    8.852    0.000 {built-in method builtins.sum}
#        52    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#         1    0.000    0.000    0.000    0.000 {built-in method gc.collect}
#     16407    0.006    0.000    0.006    0.000 {built-in method math.ceil}
#        56    0.000    0.000    0.000    0.000 {built-in method math.copysign}
#        12    0.000    0.000    0.000    0.000 {built-in method math.cos}
#       114    0.000    0.000    0.000    0.000 {built-in method math.floor}
#       226    0.000    0.000    0.000    0.000 {built-in method math.log10}
#        24    0.000    0.000    0.000    0.000 {built-in method math.radians}
#        12    0.000    0.000    0.000    0.000 {built-in method math.sin}
#         4    0.076    0.019    0.076    0.019 {built-in method matplotlib._image.resample}
#      3713    0.002    0.000    0.002    0.000 {built-in method matplotlib._path.affine_transform}
#        29    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.get_path_extents}
#         1    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.is_sorted}
#      1663    0.007    0.000    0.008    0.000 {built-in method matplotlib._path.update_path_extents}
#         1    0.019    0.019    0.019    0.019 {built-in method matplotlib._png.write_png}
#     29776    0.055    0.000    0.055    0.000 {built-in method numpy.arange}
# 433770/433762    0.374    0.000    0.374    0.000 {built-in method numpy.array}
# 489278/325790    4.746    0.000    7.414    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     32830    0.006    0.000    0.006    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#       135    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#     26780    0.004    0.000    0.004    0.000 {built-in method numpy.geterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#     13390    0.006    0.000    0.006    0.000 {built-in method numpy.seterrobj}
#     25527    0.015    0.000    0.015    0.000 {built-in method numpy.zeros}
#        44    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#        60    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.006    0.006    0.006    0.006 {built-in method scipy.interpolate.interpnd._ndim_coords_from_arrays}
#       411    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         2    0.000    0.000    0.000    0.000 {built-in method sys.is_finalizing}
#         1    0.000    0.000    0.000    0.000 {built-in method utcnow}
#         1    0.000    0.000    0.000    0.000 {dilate}
#       106    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x7fde02057040}
#     58650    0.007    0.000    0.007    0.000 {function RcParams.__getitem__ at 0x7fdd8fbbe670}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#        18    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#     28192    0.011    0.000    0.069    0.000 {method 'all' of 'numpy.ndarray' objects}
#     36126    0.026    0.000    0.075    0.000 {method 'any' of 'numpy.generic' objects}
#     14167    0.006    0.000    0.026    0.000 {method 'any' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    129774    0.010    0.000    0.010    0.000 {method 'append' of 'list' objects}
#        16    0.155    0.010    0.155    0.010 {method 'argsort' of 'numpy.ndarray' objects}
#     20408    0.022    0.000    0.022    0.000 {method 'astype' of 'numpy.generic' objects}
#     49227    0.070    0.000    0.070    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        60    0.000    0.000    0.000    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#      3376    0.002    0.000    0.058    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#     13268    0.009    0.000    0.009    0.000 {method 'copy' of 'numpy.generic' objects}
#     75549    0.149    0.000    0.149    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#       274    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#      1658    0.009    0.000    0.009    0.000 {method 'create_contour' of 'matplotlib.QuadContourGenerator' objects}
#         4    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.000    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#         1    0.000    0.000    0.000    0.000 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        12    0.000    0.000    0.000    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         7    0.002    0.000    0.002    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      1658    0.023    0.000    0.074    0.000 {method 'draw_path_collection' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        12    0.000    0.000    0.000    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         5    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#     13293    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#         4    0.029    0.007    0.029    0.007 {method 'factorize' of 'pandas._libs.hashtable.Float64HashTable' objects}
#      3378    0.005    0.000    0.005    0.000 {method 'fill' of 'numpy.ndarray' objects}
#     81367    0.068    0.000    0.068    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#       182    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#     92601    0.010    0.000    0.010    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        12    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#        60    0.000    0.000    0.000    0.000 {method 'get_descent' of 'matplotlib.ft2font.FT2Font' objects}
#         8    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#         8    0.125    0.016    0.125    0.016 {method 'get_labels_groupby' of 'pandas._libs.hashtable.Int64HashTable' objects}
#        20    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#        48    0.000    0.000    0.000    0.000 {method 'get_width_height' of 'matplotlib.ft2font.FT2Font' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         6    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         4    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.generic' objects}
#        71    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#    238975    0.018    0.000    0.018    0.000 {method 'items' of 'dict' objects}
#        36    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#     19703    0.002    0.000    0.002    0.000 {method 'lower' of 'str' objects}
#     10573    0.005    0.000    0.005    0.000 {method 'match' of 're.Pattern' objects}
#     13553    0.006    0.000    0.031    0.000 {method 'max' of 'numpy.ndarray' objects}
#     13381    0.007    0.000    0.038    0.000 {method 'min' of 'numpy.ndarray' objects}
#        62    0.002    0.000    0.002    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        29    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#     58845    0.006    0.000    0.006    0.000 {method 'pop' of 'dict' objects}
#        15    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        10    0.023    0.002    0.023    0.002 {method 'put' of 'numpy.ndarray' objects}
#     26679    0.008    0.000    0.008    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#    337790    0.650    0.000    0.650    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         9    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#       288    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#     12207    0.007    0.000    0.007    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     42946    0.100    0.000    0.100    0.000 {method 'round' of 'numpy.generic' objects}
#       173    0.003    0.000    0.003    0.000 {method 'round' of 'numpy.ndarray' objects}
#        29    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        28    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#     46076    0.051    0.000    0.051    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#        60    0.000    0.000    0.000    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#        60    0.013    0.000    0.013    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#        22    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#     23043    0.772    0.000    0.772    0.000 {method 'sort' of 'numpy.ndarray' objects}
#        24    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#      2432    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        66    0.000    0.000    0.009    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#      3348    0.024    0.000    0.024    0.000 {method 'take' of 'numpy.ndarray' objects}
#        11    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#    220826    0.026    0.000    0.026    0.000 {method 'update' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#      6637    0.001    0.000    0.001    0.000 {method 'values' of 'collections.OrderedDict' objects}
#     18877    0.002    0.000    0.002    0.000 {method 'values' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
# 56403/43131    0.040    0.000    0.106    0.000 {method 'view' of 'numpy.generic' objects}
# 63205/63201    0.024    0.000    0.183    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        10    0.003    0.000    0.003    0.000 {pandas._libs.algos.ensure_float64}
#        20    0.003    0.000    0.003    0.000 {pandas._libs.algos.ensure_int16}
#        75    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int8}
#        54    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         4    0.013    0.003    0.013    0.003 {pandas._libs.algos.groupsort_indexer}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.algos.is_lexsorted}
#        38    0.027    0.001    0.027    0.001 {pandas._libs.algos.take_1d_int64_int64}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_object_object}
#         2    0.004    0.002    0.004    0.002 {pandas._libs.algos.take_2d_axis0_float32_float32}
#         2    0.007    0.004    0.007    0.004 {pandas._libs.algos.take_2d_axis0_float64_float64}
#        10    0.010    0.001    0.010    0.001 {pandas._libs.algos.take_2d_axis1_float32_float32}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.clean_index_list}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.get_reverse_indexer}
#        20    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#        48    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_complex}
#        34    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#        68    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#       107    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#       120    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#        26    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#        20    0.000    0.000    0.000    0.000 {pandas._libs.lib.values_from_object}

# %% [markdown]
# ncalls -> total nr of calls for the function
# tottime -> total time spent inside the function called
# percall -> the average amount of time for each call
# cumtime -> the total time spent inside the function and all other calls made by that function
# percall -> the average time per call (cumtime)
#
# We want to pay attention to:
#     -> functions that not only are called most often but that spend the most time internally (those are the most worth optimizing)
#
# In this reports o tottime is very important because now we can zoom in on which functions are the slowest overall. GetFrontInWindow has the biggest tottime so that should be the one that we should optimize.
#
# No relatorio output_time.txt obtido vê-se também que a função griddata tem um tottime muito elevado.

# %%
import cProfile

cProfile.run('CCA_visualization(specificday_mur_aug[:5], days_mur_aug)')
# Out:
# /tmp/ipykernel_357230/3445070762.py:164: UserWarning: No contour levels were found within the data range.
#   c = plt.contour(X, Y, w, [thresValue])     #Create and store a set of contour lines or filled regions.
# /tmp/ipykernel_357230/3445070762.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   popBMean = popBSum/popBCount
#          211421052 function calls (209982781 primitive calls) in 396.729 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002  396.729  396.729 2193992244.py:1(CCA_visualization)
#    102000   23.904    0.000  288.930    0.003 3445070762.py:1(getFrontInWindow)
#      8525    0.004    0.000    0.004    0.000 3445070762.py:171(<listcomp>)
#      8506    0.014    0.000    0.015    0.000 3445070762.py:179(<listcomp>)
#         5    1.258    0.252  390.041   78.008 599911213.py:1(CCA_SIED)
#     42603    0.020    0.000    0.170    0.000 <__array_function__ internals>:2(all)
#    358757    0.148    0.000    1.398    0.000 <__array_function__ internals>:2(amax)
#    358744    0.152    0.000    1.701    0.000 <__array_function__ internals>:2(amin)
#    235658    0.113    0.000    1.628    0.000 <__array_function__ internals>:2(any)
#     34650    0.019    0.000    0.346    0.000 <__array_function__ internals>:2(append)
#       168    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(around)
#     17066    0.013    0.000    0.057    0.000 <__array_function__ internals>:2(atleast_1d)
#     82035    0.035    0.000    0.304    0.000 <__array_function__ internals>:2(atleast_2d)
#        12    0.000    0.000    0.028    0.002 <__array_function__ internals>:2(bincount)
#      8646    0.010    0.000    0.253    0.000 <__array_function__ internals>:2(broadcast_arrays)
#      8586    0.008    0.000    0.022    0.000 <__array_function__ internals>:2(can_cast)
#     17110    0.015    0.000    0.396    0.000 <__array_function__ internals>:2(clip)
#       103    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(column_stack)
#    232935    0.129    0.000  133.348    0.001 <__array_function__ internals>:2(concatenate)
#      1405    0.001    0.000    0.009    0.000 <__array_function__ internals>:2(copyto)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(cumsum)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(delete)
#     82039    0.038    0.000    0.474    0.000 <__array_function__ internals>:2(diff)
#     94442    0.037    0.000    0.145    0.000 <__array_function__ internals>:2(dot)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(flipud)
#     82015    0.041    0.000    5.070    0.000 <__array_function__ internals>:2(histogram)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(hstack)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(isclose)
#     17060    0.014    0.000    0.486    0.000 <__array_function__ internals>:2(linspace)
#     82015    0.044    0.000    0.877    0.000 <__array_function__ internals>:2(mean)
#      8535    0.009    0.000    0.393    0.000 <__array_function__ internals>:2(meshgrid)
#     51168    0.030    0.000    0.101    0.000 <__array_function__ internals>:2(min_scalar_type)
#     82020    0.035    0.000    0.590    0.000 <__array_function__ internals>:2(nanmax)
#     82020    0.044    0.000    0.782    0.000 <__array_function__ internals>:2(nanmin)
#    215310    0.083    0.000    0.262    0.000 <__array_function__ internals>:2(ndim)
#        58    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(nonzero)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ones_like)
#        54    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(prod)
#        56    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ptp)
#        36    0.000    0.000    0.010    0.000 <__array_function__ internals>:2(putmask)
#     34650    0.015    0.000    0.119    0.000 <__array_function__ internals>:2(ravel)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(repeat)
#     17063    0.011    0.000    0.037    0.000 <__array_function__ internals>:2(result_type)
#       168    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(round_)
#     21374    0.014    0.000    0.048    0.000 <__array_function__ internals>:2(shape)
#    116125    0.074    0.000    9.362    0.000 <__array_function__ internals>:2(sort)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(tile)
#        22    0.000    0.000    0.342    0.016 <__array_function__ internals>:2(unique)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(unravel_index)
#     82035    0.038    0.000    0.688    0.000 <__array_function__ internals>:2(vstack)
#        25    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(where)
#         6    0.000    0.000    0.005    0.001 <__array_function__ internals>:2(zeros_like)
#      8708    0.009    0.000    0.011    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#        29    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:389(parent)
#         1    0.000    0.000  396.729  396.729 <string>:1(<module>)
#      9000    0.005    0.000    0.009    0.000 <string>:1(__new__)
#        12    0.000    0.000    0.000    0.000 __init__.py:101(get_op_result_name)
#     17070    0.016    0.000    0.016    0.000 __init__.py:118(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1294(get_backend)
#       137    0.000    0.000    0.000    0.000 __init__.py:1296(is_math_text)
#     18062    0.010    0.000    0.022    0.000 __init__.py:1309(_to_unmasked_float_array)
#         2    0.000    0.000    0.000    0.000 __init__.py:1312(is_interactive)
#         2    0.000    0.000    0.000    0.000 __init__.py:1320(_check_1d)
#        11    0.000    0.000    0.000    0.000 __init__.py:138(connect)
#      8526    0.028    0.000  209.261    0.025 __init__.py:1562(inner)
#         2    0.000    0.000    0.000    0.000 __init__.py:157(_remove_proxy)
#       101    0.000    0.000    0.000    0.000 __init__.py:1598(<lambda>)
#    102308    0.064    0.000    0.186    0.000 __init__.py:1633(safe_first_element)
#     34101    0.015    0.000    0.049    0.000 __init__.py:1655(sanitize_sequence)
#        71    0.001    0.000    0.001    0.000 __init__.py:1663(normalize_kwargs)
#         1    0.000    0.000    0.000    0.000 __init__.py:170(disconnect)
#        71    0.000    0.000    0.000    0.000 __init__.py:1760(<listcomp>)
#        71    0.000    0.000    0.000    0.000 __init__.py:1765(<listcomp>)
#         4    0.000    0.000    0.001    0.000 __init__.py:183(dumps)
#     51157    0.045    0.000    0.055    0.000 __init__.py:185(process)
#     34227    0.006    0.000    0.009    0.000 __init__.py:1850(_str_equal)
#     34197    0.014    0.000    0.020    0.000 __init__.py:1860(_str_lower_equal)
#        58    0.000    0.000    0.000    0.000 __init__.py:1891(method)
#         1    0.000    0.000    0.000    0.000 __init__.py:19(get_projection_class)
#     18006    0.018    0.000    0.045    0.000 __init__.py:1956(_setattr_cm)
#      9003    0.005    0.000    0.006    0.000 __init__.py:1961(<listcomp>)
#      2162    0.017    0.000    0.053    0.000 __init__.py:1974(_warn_external)
#         1    0.000    0.000    0.000    0.000 __init__.py:1997(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:2009(add)
#     25759    0.066    0.000    0.094    0.000 __init__.py:2096(_check_isinstance)
#     51518    0.007    0.000    0.007    0.000 __init__.py:2111(<genexpr>)
#     25759    0.014    0.000    0.014    0.000 __init__.py:2113(type_name)
#     37103    0.045    0.000    0.049    0.000 __init__.py:2131(_check_in_list)
#      8527    0.003    0.000    0.003    0.000 __init__.py:223(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:359(to_filehandle)
#         2    0.000    0.000    0.000    0.000 __init__.py:415(open_file_cm)
#         1    0.000    0.000    0.000    0.000 __init__.py:44(get_projection_class)
#        12    0.000    0.000    0.001    0.000 __init__.py:448(_construct_result)
#         3    0.000    0.000    0.000    0.000 __init__.py:51(__init__)
#        12    0.000    0.000    0.007    0.001 __init__.py:518(wrapper)
#        24    0.000    0.000    0.000    0.000 __init__.py:557(__setitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:573(__init__)
#         7    0.000    0.000    0.000    0.000 __init__.py:60(__hash__)
#         2    0.000    0.000    0.000    0.000 __init__.py:601(push)
#         3    0.000    0.000    0.000    0.000 __init__.py:626(clear)
#         1    0.000    0.000    0.000    0.000 __init__.py:631(bubble)
#         1    0.000    0.000    0.000    0.000 __init__.py:705(safe_masked_invalid)
#         1    0.000    0.000    0.000    0.000 __init__.py:784(__setitem__)
#    214499    0.077    0.000    0.114    0.000 __init__.py:815(__getitem__)
#         2    0.000    0.000    0.000    0.000 __init__.py:827(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:828(<dictcomp>)
#         5    0.000    0.000    0.000    0.000 __init__.py:830(__contains__)
#    290397    0.127    0.000    0.163    0.000 __init__.py:833(clean)
#    290397    0.036    0.000    0.036    0.000 __init__.py:836(<listcomp>)
#    290395    0.335    0.000    0.586    0.000 __init__.py:882(get_siblings)
#    290395    0.056    0.000    0.056    0.000 __init__.py:886(<listcomp>)
#        25    0.000    0.000    0.007    0.000 _asarray.py:139(ascontiguousarray)
# 457363/457339    0.101    0.000    0.563    0.000 _asarray.py:14(asarray)
#        12    0.000    0.000    0.000    0.000 _asarray.py:221(require)
#        12    0.000    0.000    0.000    0.000 _asarray.py:298(<setcomp>)
#    697705    0.146    0.000    0.503    0.000 _asarray.py:86(asanyarray)
#         1    0.000    0.000    0.002    0.002 _axes.py:1414(plot)
#         1    0.000    0.000    0.002    0.002 _axes.py:5432(imshow)
#      8525    0.035    0.000  209.181    0.025 _axes.py:6334(contour)
#         1    0.000    0.000    0.000    0.000 _base.py:1116(_set_title_offset_trans)
#         8    0.000    0.000    0.000    0.000 _base.py:1202(get_aspect)
#         3    0.000    0.000    0.000    0.000 _base.py:1205(set_aspect)
#         3    0.000    0.000    0.000    0.000 _base.py:1287(set_adjustable)
#         2    0.000    0.000    0.000    0.000 _base.py:129(__init__)
#         5    0.000    0.000    0.000    0.000 _base.py:1336(get_anchor)
#         5    0.000    0.000    0.000    0.000 _base.py:1405(get_data_ratio)
#         2    0.000    0.000    0.000    0.000 _base.py:142(set_prop_cycle)
#         7    0.000    0.000    0.001    0.000 _base.py:1436(apply_aspect)
#         2    0.000    0.000    0.000    0.000 _base.py:153(__call__)
#      8526    0.482    0.000    0.483    0.000 _base.py:1728(_sci)
#      8525    0.027    0.000    0.927    0.000 _base.py:1803(add_collection)
#         1    0.000    0.000    0.000    0.000 _base.py:1826(add_image)
#         1    0.000    0.000    0.002    0.002 _base.py:1842(add_line)
#         1    0.000    0.000    0.002    0.002 _base.py:1868(_update_line_limits)
#      8526    0.018    0.000    0.163    0.000 _base.py:2009(update_datalim)
#     42628    0.035    0.000    0.669    0.000 _base.py:2045(_process_unit_info)
#     85256    0.063    0.000    0.633    0.000 _base.py:2048(_process_single_axis)
#     17049    0.007    0.000    0.007    0.000 _base.py:2133(use_sticky_edges)
#         1    0.000    0.000    0.000    0.000 _base.py:224(_getdefaults)
#         2    0.000    0.000    0.000    0.000 _base.py:232(<genexpr>)
# 17049/8525    1.193    0.000  197.848    0.023 _base.py:2332(autoscale_view)
#     17049    8.076    0.000   24.889    0.001 _base.py:2382(<listcomp>)
#     17049    8.553    0.001   24.475    0.001 _base.py:2388(<listcomp>)
# 34098/17050    0.654    0.000  100.768    0.006 _base.py:2398(handle_single_axis)
#     34098    0.010    0.000    0.010    0.000 _base.py:2405(<listcomp>)
#     34098    0.274    0.000    0.522    0.000 _base.py:2407(<listcomp>)
#     34098    0.072    0.000    0.183    0.000 _base.py:2411(<listcomp>)
#     34098    0.045    0.000    0.112    0.000 _base.py:2414(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _base.py:242(_setdefaults)
#     68196    0.019    0.000    0.024    0.000 _base.py:2432(tol)
#     51156    0.012    0.000    0.012    0.000 _base.py:2470(_get_axis_list)
#         6    0.000    0.000    0.002    0.000 _base.py:2491(_update_title_position)
#         1    0.000    0.000    0.000    0.000 _base.py:251(_makeline)
#        24    0.000    0.000    0.000    0.000 _base.py:2548(<genexpr>)
#         2    0.000    0.000    1.421    0.710 _base.py:2555(draw)
#         1    0.000    0.000    0.000    0.000 _base.py:2691(set_axisbelow)
#         2    0.000    0.000    0.003    0.001 _base.py:2727(grid)
#         2    0.000    0.000    0.001    0.000 _base.py:2884(tick_params)
#         1    0.000    0.000    0.000    0.000 _base.py:2971(set_axis_on)
#     17049    0.015    0.000    0.165    0.000 _base.py:2994(xaxis_inverted)
# 17054/8530    0.013    0.000   97.363    0.011 _base.py:3008(get_xbound)
# 17049/8525    0.036    0.000   97.798    0.011 _base.py:3024(set_xbound)
# 17054/8530    0.037    0.000   97.356    0.011 _base.py:3064(get_xlim)
#     68204    0.126    0.000    0.380    0.000 _base.py:3087(_validate_converted_limits)
#         1    0.000    0.000    0.000    0.000 _base.py:310(_plot_args)
#     17051    0.114    0.000    0.933    0.000 _base.py:3104(set_xlim)
#         3    0.000    0.000    0.000    0.000 _base.py:321(<genexpr>)
#     34100    0.027    0.000    0.044    0.000 _base.py:3241(get_xscale)
#     17049    0.009    0.000    0.142    0.000 _base.py:3405(yaxis_inverted)
#     17054    0.011    0.000    0.157    0.000 _base.py:3419(get_ybound)
#     17049    0.032    0.000    1.083    0.000 _base.py:3435(set_ybound)
#     17054    0.027    0.000    0.146    0.000 _base.py:3475(get_ylim)
#     17051    0.094    0.000    0.751    0.000 _base.py:3498(set_ylim)
#         1    0.000    0.000    0.000    0.000 _base.py:363(<listcomp>)
#     34100    0.014    0.000    0.027    0.000 _base.py:3635(get_yscale)
#         1    0.000    0.000    0.008    0.008 _base.py:378(__init__)
#         1    0.000    0.000    0.000    0.000 _base.py:3884(set_navigate)
#         1    0.000    0.000    0.000    0.000 _base.py:3900(set_navigate_mode)
#     34105    0.651    0.000    0.666    0.000 _base.py:4215(get_children)
#         3    0.000    0.000    0.015    0.005 _base.py:4247(get_default_bbox_extra_artists)
#         3    0.008    0.003    0.015    0.005 _base.py:4267(<listcomp>)
#         2    0.087    0.044    3.591    1.795 _base.py:4270(get_tightbbox)
#         2    0.005    0.003    0.013    0.007 _base.py:4367(<listcomp>)
#        22    0.000    0.000    0.000    0.000 _base.py:535(get_window_extent)
#         1    0.000    0.000    0.001    0.001 _base.py:553(_init_axis)
#         1    0.000    0.000    0.000    0.000 _base.py:563(set_figure)
# 68454/34358    0.125    0.000   97.455    0.003 _base.py:583(_unstale_viewLim)
#    136908    0.022    0.000    0.022    0.000 _base.py:586(<genexpr>)
#    136908    0.014    0.000    0.014    0.000 _base.py:588(<genexpr>)
# 68452/34356    0.028    0.000   97.470    0.003 _base.py:597(viewLim)
#      8526    0.004    0.000    0.004    0.000 _base.py:604(_request_autoscale_view)
#         1    0.000    0.000    0.000    0.000 _base.py:612(_set_lim_and_transforms)
#   353/195    0.000    0.000    0.001    0.000 _base.py:648(get_xaxis_transform)
#        39    0.000    0.000    0.001    0.000 _base.py:672(get_xaxis_text1_transform)
#        39    0.000    0.000    0.000    0.000 _base.py:698(get_xaxis_text2_transform)
#   335/185    0.000    0.000    0.001    0.000 _base.py:724(get_yaxis_transform)
#        37    0.000    0.000    0.001    0.000 _base.py:748(get_yaxis_text1_transform)
#        37    0.000    0.000    0.000    0.000 _base.py:774(get_yaxis_text2_transform)
#         2    0.000    0.000    0.000    0.000 _base.py:800(_update_transScale)
#       6/5    0.000    0.000    0.000    0.000 _base.py:810(get_position)
#         7    0.000    0.000    0.000    0.000 _base.py:859(_set_position)
#         3    0.000    0.000    0.000    0.000 _base.py:886(set_axes_locator)
#         8    0.000    0.000    0.000    0.000 _base.py:897(get_axes_locator)
#      8530    0.019    0.000    0.038    0.000 _base.py:903(_set_artist_props)
#         1    0.000    0.000    0.000    0.000 _base.py:913(_gen_axes_patch)
#         1    0.000    0.000    0.000    0.000 _base.py:930(_gen_axes_spines)
#         5    0.000    0.000    0.000    0.000 _base.py:945(<genexpr>)
#         1    0.000    0.000    0.006    0.006 _base.py:948(cla)
#         6    0.000    0.000    0.011    0.002 _decorators.py:225(wrapper)
#       580    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#       580    0.000    0.000    0.002    0.000 _dtype.py:307(_name_includes_bit_suffix)
#       580    0.001    0.000    0.003    0.000 _dtype.py:321(_name_get)
#        91    0.000    0.000    0.001    0.000 _dtype.py:34(__str__)
#     17110    0.040    0.000    0.319    0.000 _methods.py:106(_clip)
#     82015    0.345    0.000    0.695    0.000 _methods.py:143(_mean)
#        56    0.000    0.000    0.000    0.000 _methods.py:245(_ptp)
#     51468    0.013    0.000    0.236    0.000 _methods.py:37(_amax)
#     51288    0.015    0.000    0.267    0.000 _methods.py:41(_amin)
#        82    0.000    0.000    0.027    0.000 _methods.py:45(_sum)
#    253850    0.060    0.000    0.359    0.000 _methods.py:53(_any)
#    144949    0.040    0.000    0.381    0.000 _methods.py:56(_all)
#     82015    0.073    0.000    0.097    0.000 _methods.py:59(_count_reduce_items)
#     34220    0.104    0.000    0.201    0.000 _methods.py:72(_clip_dep_is_scalar_nan)
#     34220    0.011    0.000    0.014    0.000 _methods.py:82(_clip_dep_is_byte_swapped)
#     17110    0.064    0.000    0.064    0.000 _methods.py:87(_clip_dep_invoke_with_casting)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:109(set_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:115(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:29(get_fig_manager)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:65(destroy_all)
#         2    0.000    0.000    0.000    0.000 _pylab_helpers.py:85(get_all_fig_managers)
#     17054    0.013    0.000    0.015    0.000 _pylab_helpers.py:99(get_active)
#         1    0.000    0.000    0.000    0.000 _subplots.py:117(get_subplotspec)
#         1    0.000    0.000    0.000    0.000 _subplots.py:129(update_params)
#         1    0.000    0.000    0.008    0.008 _subplots.py:18(__init__)
#     68390    0.089    0.000    0.095    0.000 _ufunc_config.py:132(geterr)
#     68390    0.117    0.000    0.275    0.000 _ufunc_config.py:32(seterr)
#     34195    0.014    0.000    0.014    0.000 _ufunc_config.py:429(__init__)
#     34195    0.032    0.000    0.217    0.000 _ufunc_config.py:433(__enter__)
#     34195    0.024    0.000    0.115    0.000 _ufunc_config.py:438(__exit__)
#        54    0.000    0.000    0.000    0.000 _validators.py:207(validate_bool_kwarg)
#         6    0.000    0.000    0.000    0.000 _validators.py:217(validate_axis_style_args)
#        24    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#    299502    0.054    0.000    0.138    0.000 abc.py:96(__instancecheck__)
#       157    0.001    0.000    0.003    0.000 algorithms.py:1436(_get_take_nd_function)
#       157    0.002    0.000    0.156    0.001 algorithms.py:1565(take_nd)
#        12    0.000    0.000    0.002    0.000 algorithms.py:171(_reconstruct_data)
#        12    0.000    0.000    0.021    0.002 algorithms.py:1940(safe_sort)
#        12    0.000    0.000    0.000    0.000 algorithms.py:205(_ensure_arraylike)
#        12    0.000    0.000    0.000    0.000 algorithms.py:247(_get_values_for_rank)
#        12    0.000    0.000    0.000    0.000 algorithms.py:255(_get_data_algo)
#        12    0.000    0.000    0.000    0.000 algorithms.py:264(_check_object_for_strings)
#        12    0.000    0.000    0.092    0.008 algorithms.py:456(_factorize_array)
#        12    0.000    0.000    0.115    0.010 algorithms.py:585(factorize)
#        24    0.000    0.000    0.000    0.000 algorithms.py:64(_ensure_data)
#        12    0.005    0.000    0.005    0.000 array_ops.py:202(comparison_op)
#        22    0.000    0.000    0.000    0.000 arraysetops.py:136(_unpack_tuple)
#        22    0.000    0.000    0.000    0.000 arraysetops.py:144(_unique_dispatcher)
#        22    0.000    0.000    0.342    0.016 arraysetops.py:149(unique)
#        22    0.010    0.000    0.342    0.016 arraysetops.py:309(_unique1d)
#      8986    0.008    0.000    0.276    0.000 artist.py:1006(<listcomp>)
#      8527    0.001    0.000    0.001    0.000 artist.py:1013(get_label)
#      8528    0.008    0.000    0.014    0.000 artist.py:1017(set_label)
#         2    0.000    0.000    0.000    0.000 artist.py:1033(get_zorder)
#      8683    0.008    0.000    0.015    0.000 artist.py:1037(set_zorder)
# 145726570   32.065    0.000   32.065    0.000 artist.py:1052(sticky_edges)
#        60    0.000    0.000    0.000    0.000 artist.py:1074(update_from)
#        70    0.000    0.000    0.001    0.000 artist.py:1095(set)
#      8530    0.002    0.000    0.002    0.000 artist.py:1201(mouseover)
#     17050    0.012    0.000    0.039    0.000 artist.py:163(have_units)
#     51150    0.010    0.000    0.015    0.000 artist.py:166(<genexpr>)
#     60256    0.031    0.000    0.175    0.000 artist.py:168(convert_xunits)
#     60254    0.025    0.000    0.131    0.000 artist.py:180(convert_yunits)
#    260320    0.030    0.000    0.030    0.000 artist.py:192(axes)
#     17613    0.007    0.000    0.007    0.000 artist.py:197(axes)
# 326324/230574    0.168    0.000    0.260    0.000 artist.py:217(stale)
#     17074    0.012    0.000    0.020    0.000 artist.py:250(_get_clipping_extent_bbox)
#     25605    0.051    0.000    2.755    0.000 artist.py:267(get_tightbbox)
#   17240/2    0.020    0.000    1.426    0.713 artist.py:30(draw_wrapper)
#     61523    0.019    0.000    0.023    0.000 artist.py:336(pchanged)
#      8530    0.001    0.000    0.001    0.000 artist.py:350(is_transform_set)
#      8924    0.005    0.000    0.012    0.000 artist.py:358(set_transform)
#     51485    0.019    0.000    0.025    0.000 artist.py:371(get_transform)
#     26631    0.021    0.000    0.082    0.000 artist.py:49(_stale_axes_callback)
#         2    0.000    0.000    0.000    0.000 artist.py:566(get_url)
#         1    0.000    0.000    0.000    0.000 artist.py:570(set_url)
#     17146    0.003    0.000    0.003    0.000 artist.py:580(get_gid)
#     17064    0.005    0.000    0.011    0.000 artist.py:594(get_snap)
#     17088    0.002    0.000    0.002    0.000 artist.py:633(get_sketch_params)
#     17112    0.001    0.000    0.001    0.000 artist.py:688(get_path_effects)
#         5    0.000    0.000    0.000    0.000 artist.py:691(get_figure)
#      8999    0.008    0.000    0.014    0.000 artist.py:695(set_figure)
#         3    0.000    0.000    0.000    0.000 artist.py:719(set_clip_box)
#      8541    0.047    0.000    0.849    0.000 artist.py:731(set_clip_path)
#      9000    0.040    0.000    0.061    0.000 artist.py:74(__init__)
#        26    0.000    0.000    0.000    0.000 artist.py:793(get_alpha)
#     43644    0.006    0.000    0.006    0.000 artist.py:800(get_visible)
#    326326    0.034    0.000    0.034    0.000 artist.py:804(get_animated)
#     25613    0.003    0.000    0.003    0.000 artist.py:808(get_in_layout)
#     42679    0.007    0.000    0.007    0.000 artist.py:819(get_clip_on)
#     42681    0.006    0.000    0.006    0.000 artist.py:823(get_clip_box)
#     51206    0.006    0.000    0.006    0.000 artist.py:827(get_clip_path)
#     17114    0.013    0.000    0.075    0.000 artist.py:858(_set_gc_clip)
#     34480    0.004    0.000    0.004    0.000 artist.py:868(get_rasterized)
#     34480    0.003    0.000    0.003    0.000 artist.py:888(get_agg_filter)
#      8601    0.007    0.000    0.013    0.000 artist.py:923(set_alpha)
#       429    0.000    0.000    0.000    0.000 artist.py:937(set_visible)
#         1    0.000    0.000    0.000    0.000 artist.py:961(set_in_layout)
#      8986    0.037    0.000    0.406    0.000 artist.py:974(update)
#     17280    0.026    0.000    0.268    0.000 artist.py:978(_update_property)
#     34098    0.043    0.000    0.283    0.000 axis.py:1010(get_inverted)
#         4    0.000    0.000    0.000    0.000 axis.py:1048(_set_artist_props)
#        28    0.001    0.000    0.051    0.002 axis.py:1098(_update_ticks)
#        28    0.000    0.000    0.011    0.000 axis.py:1171(_get_tick_bboxes)
#        28    0.000    0.000    0.011    0.000 axis.py:1173(<listcomp>)
#        28    0.000    0.000    0.000    0.000 axis.py:1175(<listcomp>)
#        10    0.000    0.000    0.047    0.005 axis.py:1178(get_tightbbox)
#        30    0.000    0.000    0.000    0.000 axis.py:1198(<genexpr>)
#        10    0.000    0.000    0.000    0.000 axis.py:1204(<listcomp>)
#         4    0.000    0.000    0.029    0.007 axis.py:1219(draw)
#         2    0.000    0.000    0.008    0.004 axis.py:1274(get_majorticklabels)
#         2    0.000    0.000    0.000    0.000 axis.py:1277(<listcomp>)
#         2    0.000    0.000    0.000    0.000 axis.py:1278(<listcomp>)
#         2    0.000    0.000    0.008    0.004 axis.py:1288(get_ticklabels)
#        30    0.000    0.000    0.021    0.001 axis.py:1346(get_majorticklocs)
#        28    0.000    0.000    0.019    0.001 axis.py:1350(get_minorticklocs)
#        28    0.000    0.000    0.000    0.000 axis.py:1363(<listcomp>)
#        12    0.000    0.000    0.001    0.000 axis.py:1398(_copy_tick_props)
#     68200    0.031    0.000    0.043    0.000 axis.py:1412(get_major_locator)
#        30    0.000    0.000    0.008    0.000 axis.py:1428(get_major_ticks)
#        28    0.000    0.000    0.000    0.000 axis.py:1442(get_minor_ticks)
#         4    0.000    0.000    0.003    0.001 axis.py:1456(grid)
#         4    0.000    0.000    0.000    0.000 axis.py:1486(<dictcomp>)
#     51154    0.041    0.000    0.552    0.000 axis.py:1504(update_units)
#        76    0.000    0.000    0.000    0.000 axis.py:153(<dictcomp>)
#     85252    0.021    0.000    0.021    0.000 axis.py:1559(have_units)
#     85322    0.032    0.000    0.205    0.000 axis.py:1562(convert_units)
#        12    0.000    0.000    0.000    0.000 axis.py:1579(set_units)
#        16    0.000    0.000    0.000    0.000 axis.py:1620(set_major_formatter)
#        16    0.000    0.000    0.000    0.000 axis.py:1634(set_minor_formatter)
#        16    0.000    0.000    0.000    0.000 axis.py:1648(set_major_locator)
#        16    0.000    0.000    0.000    0.000 axis.py:1664(set_minor_locator)
#        18    0.000    0.000    0.000    0.000 axis.py:1828(_get_ticks_position)
#        54    0.000    0.000    0.000    0.000 axis.py:1844(<genexpr>)
#        18    0.000    0.000    0.000    0.000 axis.py:1865(get_label_position)
#     34324    0.025    0.000    0.242    0.000 axis.py:1891(getter)
#        39    0.000    0.000    0.021    0.001 axis.py:1938(_get_tick)
#         1    0.000    0.000    0.000    0.000 axis.py:1945(_get_label)
#         1    0.000    0.000    0.000    0.000 axis.py:1963(_get_offset_text)
#        76    0.000    0.000    0.000    0.000 axis.py:197(_set_labelrotation)
#         7    0.000    0.000    0.014    0.002 axis.py:1992(_get_tick_boxes_siblings)
#         7    0.000    0.000    0.016    0.002 axis.py:2011(_update_label_position)
#         7    0.000    0.000    0.001    0.000 axis.py:2054(_update_offset_text_position)
#        18    0.000    0.000    0.000    0.000 axis.py:2147(get_ticks_position)
#        76    0.000    0.000    0.000    0.000 axis.py:215(get_tick_padding)
#     17051    0.009    0.000    0.017    0.000 axis.py:2160(get_minpos)
#        29    0.000    0.000    0.017    0.001 axis.py:2187(get_tick_space)
#        37    0.000    0.000    0.019    0.001 axis.py:2225(_get_tick)
#         1    0.000    0.000    0.000    0.000 axis.py:2232(_get_label)
#         1    0.000    0.000    0.000    0.000 axis.py:2252(_get_offset_text)
#         7    0.000    0.000    0.013    0.002 axis.py:2284(_get_tick_boxes_siblings)
#         6    0.000    0.000    0.001    0.000 axis.py:229(set_clip_path)
#         7    0.000    0.000    0.015    0.002 axis.py:2303(_update_label_position)
#         7    0.000    0.000    0.000    0.000 axis.py:2345(_update_offset_text_position)
#     17051    0.009    0.000    0.016    0.000 axis.py:2460(get_minpos)
#        29    0.000    0.000    0.016    0.001 axis.py:2487(get_tick_space)
#       224    0.000    0.000    0.000    0.000 axis.py:285(get_loc)
#        24    0.000    0.000    0.006    0.000 axis.py:289(draw)
#       224    0.000    0.000    0.001    0.000 axis.py:301(set_label1)
#       224    0.000    0.000    0.001    0.000 axis.py:314(set_label2)
#       380    0.000    0.000    0.001    0.000 axis.py:325(_set_artist_props)
#        14    0.000    0.000    0.001    0.000 axis.py:334(_apply_params)
#        70    0.000    0.000    0.000    0.000 axis.py:342(<genexpr>)
#        14    0.000    0.000    0.000    0.000 axis.py:361(<dictcomp>)
#        14    0.000    0.000    0.000    0.000 axis.py:372(<dictcomp>)
#        14    0.000    0.000    0.000    0.000 axis.py:383(<dictcomp>)
#        39    0.000    0.000    0.001    0.000 axis.py:407(_get_text1_transform)
#        39    0.000    0.000    0.001    0.000 axis.py:410(_get_text2_transform)
#        39    0.000    0.000    0.000    0.000 axis.py:413(apply_tickdir)
#        39    0.000    0.000    0.003    0.000 axis.py:427(_get_text1)
#        39    0.000    0.000    0.002    0.000 axis.py:444(_get_text2)
#        39    0.000    0.000    0.005    0.000 axis.py:459(_get_tick1line)
#        39    0.000    0.000    0.004    0.000 axis.py:470(_get_tick2line)
#        39    0.000    0.000    0.005    0.000 axis.py:485(_get_gridline)
#       165    0.000    0.000    0.001    0.000 axis.py:501(update_position)
#        37    0.000    0.000    0.001    0.000 axis.py:523(_get_text1_transform)
#        37    0.000    0.000    0.001    0.000 axis.py:526(_get_text2_transform)
#        37    0.000    0.000    0.000    0.000 axis.py:529(apply_tickdir)
#        37    0.000    0.000    0.002    0.000 axis.py:544(_get_text1)
#        37    0.000    0.000    0.002    0.000 axis.py:559(_get_text2)
#        76    0.001    0.000    0.040    0.001 axis.py:56(__init__)
#        37    0.000    0.000    0.004    0.000 axis.py:574(_get_tick1line)
#        37    0.000    0.000    0.004    0.000 axis.py:589(_get_tick2line)
#        37    0.000    0.000    0.005    0.000 axis.py:603(_get_gridline)
#       135    0.000    0.000    0.001    0.000 axis.py:618(update_position)
#         4    0.000    0.000    0.000    0.000 axis.py:645(__init__)
#     68286    0.012    0.000    0.012    0.000 axis.py:649(locator)
#        32    0.000    0.000    0.000    0.000 axis.py:653(locator)
#       188    0.000    0.000    0.000    0.000 axis.py:662(formatter)
#        32    0.000    0.000    0.000    0.000 axis.py:666(formatter)
#       6/4    0.000    0.000    0.003    0.001 axis.py:687(__get__)
#         2    0.000    0.000    0.001    0.000 axis.py:744(__init__)
#        28    0.000    0.000    0.000    0.000 axis.py:788(get_remove_overlapping_locs)
#     34364    0.026    0.000    0.095    0.000 axis.py:819(get_transform)
#     68200    0.029    0.000    0.029    0.000 axis.py:822(get_scale)
#        16    0.000    0.000    0.001    0.000 axis.py:825(_set_scale)
#     34102    0.024    0.000    0.060    0.000 axis.py:834(limit_range_for_scale)
#        12    0.000    0.000    0.001    0.000 axis.py:841(cla)
#        16    0.000    0.000    0.000    0.000 axis.py:864(reset_ticks)
#         8    0.000    0.000    0.003    0.000 axis.py:884(set_tick_params)
#         8    0.000    0.000    0.000    0.000 axis.py:922(_translate_tick_kw)
#         2    0.000    0.000    0.002    0.001 axis.py:967(set_clip_path)
#         2    0.000    0.000    0.000    0.000 backend_agg.py:108(_update_methods)
#         7    0.000    0.000    0.011    0.002 backend_agg.py:125(draw_path)
#        12    0.000    0.000    0.001    0.000 backend_agg.py:170(draw_text)
#        48    0.000    0.000    0.002    0.000 backend_agg.py:196(get_text_width_height_descent)
#        24    0.000    0.000    0.000    0.000 backend_agg.py:239(get_canvas_width_height)
#        60    0.000    0.000    0.001    0.000 backend_agg.py:243(_get_agg_font)
#        48    0.000    0.000    0.000    0.000 backend_agg.py:256(points_to_pixels)
#         4    0.000    0.000    0.000    0.000 backend_agg.py:272(option_image_nocomposite)
#         2    0.000    0.000    0.946    0.473 backend_agg.py:384(draw)
#         3    0.000    0.000    0.001    0.000 backend_agg.py:398(get_renderer)
#         2    0.000    0.000    0.971    0.486 backend_agg.py:454(print_png)
#        60    0.000    0.000    0.000    0.000 backend_agg.py:55(get_hinting_flag)
#         2    0.001    0.000    0.001    0.001 backend_agg.py:86(__init__)
#      8557    0.001    0.000    0.001    0.000 backend_bases.py:1001(get_hatch_color)
#      8557    0.001    0.000    0.001    0.000 backend_bases.py:1009(get_hatch_linewidth)
#      8557    0.001    0.000    0.001    0.000 backend_bases.py:1013(get_sketch_params)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1236(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1265(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:151(__init__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1541(_get_renderer)
#      8572    0.001    0.000    0.001    0.000 backend_bases.py:155(open_group)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1553(Done)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1556(_draw)
#      8572    0.001    0.000    0.001    0.000 backend_bases.py:162(close_group)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1635(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1687(is_saving)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1704(draw_event)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1929(draw)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1982(_get_output_canvas)
#         1    0.003    0.003    6.299    6.299 backend_bases.py:2001(print_figure)
#         7    0.000    0.000    0.000    0.000 backend_bases.py:2185(mpl_connect)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2240(mpl_disconnect)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2564(__init__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2582(notify_axes_change)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2597(destroy)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3351(new_figure_manager)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3360(new_figure_manager_given_figure)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:450(get_image_magnification)
#        24    0.000    0.000    0.000    0.000 backend_bases.py:637(flipy)
#     17114    0.006    0.000    0.080    0.000 backend_bases.py:656(new_gc)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:716(_draw_disabled)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:724(<dictcomp>)
#     25701    0.002    0.000    0.002    0.000 backend_bases.py:725(<lambda>)
#     17114    0.024    0.000    0.074    0.000 backend_bases.py:737(__init__)
#     17114    0.001    0.000    0.001    0.000 backend_bases.py:778(restore)
#      8557    0.001    0.000    0.001    0.000 backend_bases.py:807(get_clip_path)
#      8557    0.001    0.000    0.001    0.000 backend_bases.py:817(get_dashes)
#      8557    0.001    0.000    0.001    0.000 backend_bases.py:857(get_snap)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:868(set_alpha)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:885(set_antialiased)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:890(set_capstyle)
#     17054    0.002    0.000    0.002    0.000 backend_bases.py:895(set_clip_rectangle)
#     17114    0.011    0.000    0.060    0.000 backend_bases.py:901(set_clip_path)
#        14    0.000    0.000    0.000    0.000 backend_bases.py:912(set_dashes)
#       100    0.000    0.000    0.000    0.000 backend_bases.py:938(set_foreground)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:958(set_joinstyle)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:963(set_linewidth)
#        38    0.000    0.000    0.000    0.000 backend_bases.py:967(set_url)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:971(set_gid)
#     17088    0.002    0.000    0.002    0.000 backend_bases.py:975(set_snap)
#      8557    0.001    0.000    0.001    0.000 backend_bases.py:990(get_hatch)
#      8557    0.002    0.000    0.003    0.000 backend_bases.py:994(get_hatch_path)
#         1    0.000    0.000    0.008    0.008 backend_inline.py:226(_fetch_figure_metadata)
#         1    0.000    0.000    6.309    6.309 backend_inline.py:23(show)
#         1    0.000    0.000    0.008    0.008 backend_inline.py:231(<listcomp>)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:242(_is_light)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:250(_is_transparent)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:59(draw_if_interactive)
#         1    0.000    0.000    0.000    0.000 base.py:1026(__iter__)
#       228    0.000    0.000    0.000    0.000 base.py:1182(name)
#         6    0.000    0.000    0.000    0.000 base.py:1197(_validate_names)
#        12    0.000    0.000    0.000    0.000 base.py:1217(_get_names)
#         6    0.000    0.000    0.000    0.000 base.py:1220(_set_names)
#         6    0.000    0.000    0.000    0.000 base.py:1250(set_names)
#         6    0.000    0.000    0.000    0.000 base.py:1329(rename)
#        36    0.000    0.000    0.000    0.000 base.py:1383(nlevels)
#         6    0.000    0.000    0.000    0.000 base.py:1484(droplevel)
#        12    0.000    0.000    0.000    0.000 base.py:1506(<genexpr>)
#     36/12    0.000    0.000    0.001    0.000 base.py:1581(is_monotonic)
#        24    0.000    0.000    0.000    0.000 base.py:1588(is_monotonic_increasing)
#        24    0.000    0.000    0.001    0.000 base.py:1656(is_unique)
#        24    0.000    0.000    0.000    0.000 base.py:1667(is_boolean)
#        12    0.000    0.000    0.000    0.000 base.py:1679(is_object)
#         6    0.000    0.000    0.000    0.000 base.py:1682(is_categorical)
#        30    0.000    0.000    0.000    0.000 base.py:1730(inferred_type)
#        12    0.000    0.000    0.000    0.000 base.py:1755(_isnan)
#        12    0.000    0.000    0.000    0.000 base.py:1775(hasnans)
#       840    0.000    0.000    0.000    0.000 base.py:194(construct_from_string)
#         6    0.000    0.000    0.012    0.002 base.py:203(_obj_with_exclusions)
#       946    0.000    0.000    0.002    0.000 base.py:247(is_dtype)
#         6    0.000    0.000    1.189    0.198 base.py:254(_try_aggregate_string_function)
#        54    0.000    0.000    0.001    0.000 base.py:2637(get_loc)
#        24    0.000    0.000    0.003    0.000 base.py:2706(get_indexer)
#     60/42    0.001    0.000    0.003    0.000 base.py:276(__new__)
#         6    0.000    0.000    1.190    0.198 base.py:285(_aggregate)
#         6    0.000    0.000    0.000    0.000 base.py:2967(_convert_listlike_indexer)
#         6    0.000    0.000    0.000    0.000 base.py:3004(_convert_arr_indexer)
#         6    0.000    0.000    0.000    0.000 base.py:3044(_convert_list_indexer)
#         6    0.000    0.000    0.000    0.000 base.py:3084(_can_reindex)
#        12    0.000    0.000    0.001    0.000 base.py:3101(reindex)
#       360    0.000    0.000    0.000    0.000 base.py:3639(values)
#        54    0.000    0.000    0.000    0.000 base.py:3671(_values)
#        48    0.000    0.000    0.000    0.000 base.py:3701(_internal_get_values)
#        72    0.000    0.000    0.000    0.000 base.py:3898(__contains__)
#        18    0.000    0.000    0.000    0.000 base.py:3912(__getitem__)
#        12    0.000    0.000    0.001    0.000 base.py:3950(_can_hold_identifiers_and_holds_name)
#        36    0.000    0.000    0.000    0.000 base.py:4047(equals)
#         6    0.000    0.000    0.000    0.000 base.py:4077(identical)
#         6    0.000    0.000    0.001    0.000 base.py:4489(get_indexer_for)
#        24    0.000    0.000    0.000    0.000 base.py:4506(_maybe_promote)
#       234    0.000    0.000    0.001    0.000 base.py:472(_simple_new)
#         6    0.000    0.000    0.000    0.000 base.py:4723(_maybe_cast_indexer)
#         6    0.000    0.000    0.000    0.000 base.py:4963(delete)
#         6    0.000    0.000    0.001    0.000 base.py:4993(drop)
#       192    0.000    0.000    0.000    0.000 base.py:505(_get_attributes_dict)
#       192    0.000    0.000    0.000    0.000 base.py:509(<dictcomp>)
#        12    0.000    0.000    0.000    0.000 base.py:5237(shape)
#       192    0.001    0.000    0.002    0.000 base.py:526(_shallow_copy)
#       377    0.000    0.000    0.003    0.000 base.py:5294(ensure_index)
#        12    0.000    0.000    0.000    0.000 base.py:5361(_ensure_has_len)
#       133    0.000    0.000    0.000    0.000 base.py:5394(maybe_extract_name)
#        18    0.000    0.000    0.000    0.000 base.py:5410(_maybe_cast_with_dtype)
#        18    0.000    0.000    0.000    0.000 base.py:5464(_maybe_cast_data_without_dtype)
#        48    0.000    0.000    0.000    0.000 base.py:573(is_)
#       264    0.000    0.000    0.000    0.000 base.py:592(_reset_identity)
#        48    0.000    0.000    0.000    0.000 base.py:602(_engine)
#        54    0.000    0.000    0.000    0.000 base.py:609(<lambda>)
#       108    0.000    0.000    0.000    0.000 base.py:61(_reset_cache)
#       921    0.000    0.000    0.000    0.000 base.py:615(__len__)
#        84    0.000    0.000    0.000    0.000 base.py:638(dtype)
#        12    0.000    0.000    0.000    0.000 base.py:666(size)
#        12    0.000    0.000    0.000    0.000 base.py:741(to_numpy)
#        36    0.000    0.000    0.001    0.000 base.py:744(take)
#        36    0.000    0.000    0.000    0.000 base.py:766(_assert_take_fillable)
#        84    0.000    0.000    0.000    0.000 base.py:853(_ndarray_values)
#       158    0.000    0.000    0.001    0.000 blocks.py:118(__init__)
#        36    0.000    0.000    0.062    0.002 blocks.py:1277(take_nd)
#       158    0.000    0.000    0.000    0.000 blocks.py:129(_check_ndim)
#        12    0.000    0.000    0.000    0.000 blocks.py:187(is_categorical_astype)
#        12    0.000    0.000    0.000    0.000 blocks.py:202(external_values)
#        27    0.000    0.000    0.000    0.000 blocks.py:213(internal_values)
#        24    0.000    0.000    0.000    0.000 blocks.py:219(array_values)
#        31    0.000    0.000    0.000    0.000 blocks.py:225(get_values)
#        36    0.000    0.000    0.000    0.000 blocks.py:243(fill_value)
#       536    0.000    0.000    0.000    0.000 blocks.py:247(mgr_locs)
#       170    0.000    0.000    0.000    0.000 blocks.py:251(mgr_locs)
#         1    0.000    0.000    0.000    0.000 blocks.py:2597(__init__)
#        30    0.000    0.000    0.001    0.000 blocks.py:265(make_block)
#        78    0.000    0.000    0.001    0.000 blocks.py:275(make_block_same_class)
#        80    0.000    0.000    0.002    0.000 blocks.py:2987(get_block_type)
#       158    0.000    0.000    0.003    0.000 blocks.py:3033(make_block)
#        42    0.000    0.000    0.000    0.000 blocks.py:3059(_extend_blocks)
#        24    0.000    0.000    0.000    0.000 blocks.py:3078(_block_shape)
#        55    0.000    0.000    0.000    0.000 blocks.py:335(shape)
#       255    0.000    0.000    0.000    0.000 blocks.py:339(dtype)
#        91    0.000    0.000    0.001    0.000 blocks.py:343(ftype)
#        18    0.000    0.000    0.000    0.000 blocks.py:365(iget)
#        24    0.000    0.000    0.007    0.000 blocks.py:385(apply)
#        12    0.000    0.000    0.007    0.001 blocks.py:554(astype)
#         6    0.000    0.000    0.003    0.001 blocks.py:650(convert)
#        24    0.000    0.000    0.010    0.000 blocks.py:694(copy)
#        37    0.000    0.000    0.000    0.000 cast.py:1088(maybe_castable)
#        24    0.000    0.000    0.000    0.000 cast.py:1102(maybe_infer_to_datetimelike)
#        25    0.000    0.000    0.000    0.000 cast.py:1209(maybe_cast_to_datetime)
#         6    0.000    0.000    0.000    0.000 cast.py:1458(construct_1d_object_array_from_listlike)
#        25    0.000    0.000    0.000    0.000 cast.py:1483(construct_1d_ndarray_preserving_na)
#         6    0.000    0.000    0.006    0.001 cast.py:167(maybe_downcast_numeric)
#        78    0.001    0.000    0.002    0.000 cast.py:347(maybe_promote)
#        78    0.000    0.000    0.000    0.000 cast.py:503(_ensure_dtype_type)
#        84    0.000    0.000    0.009    0.000 cast.py:757(coerce_indexer_dtype)
#        12    0.000    0.000    0.000    0.000 categorical.py:312(__init__)
#        12    0.000    0.000    0.000    0.000 categorical.py:396(categories)
#        24    0.000    0.000    0.000    0.000 categorical.py:446(dtype)
#        12    0.000    0.000    0.001    0.000 categorical.py:592(from_codes)
#        24    0.000    0.000    0.000    0.000 categorical.py:662(_get_codes)
#     34102    0.040    0.000    0.403    0.000 cm.py:113(get_cmap)
#     17051    0.044    0.000    0.483    0.000 cm.py:148(__init__)
#     17052    0.082    0.000    3.976    0.000 cm.py:178(to_rgba)
#      8525    0.003    0.000    0.003    0.000 cm.py:248(set_array)
#         2    0.000    0.000    0.000    0.000 cm.py:258(get_array)
#      8526    0.010    0.000    1.985    0.000 cm.py:347(autoscale_None)
#     17051    0.028    0.000    0.051    0.000 cm.py:374(changed)
#      8525    0.049    0.000    1.778    0.000 collections.py:1253(__init__)
#      8525    0.018    0.000    0.097    0.000 collections.py:1361(set_segments)
#      8525    0.011    0.000    0.066    0.000 collections.py:1374(<listcomp>)
#      8525    0.009    0.000    0.341    0.000 collections.py:1410(set_color)
#     42625    0.007    0.000    0.007    0.000 collections.py:167(get_paths)
#     34100    0.004    0.000    0.004    0.000 collections.py:173(get_transforms)
#     42625    0.013    0.000    0.017    0.000 collections.py:176(get_offset_transform)
#     25575    0.070    0.000    1.225    0.000 collections.py:183(get_datalim)
#     25575    0.023    0.000    1.267    0.000 collections.py:248(get_window_extent)
#     17050    0.025    0.000    0.093    0.000 collections.py:253(_prepare_points)
#     17050    0.119    0.000    1.252    0.000 collections.py:290(draw)
#      8525    0.004    0.000    0.004    0.000 collections.py:375(set_pickradius)
#      8525    0.005    0.000    0.008    0.000 collections.py:422(set_urls)
#      8525    0.004    0.000    0.006    0.000 collections.py:434(set_hatch)
#      8525    0.010    0.000    0.018    0.000 collections.py:499(set_offset_position)
#      8525    0.022    0.000    0.122    0.000 collections.py:527(set_linewidth)
#      8525    0.019    0.000    0.089    0.000 collections.py:549(set_linestyle)
#      8525    0.005    0.000    0.013    0.000 collections.py:581(<listcomp>)
#     17050    0.025    0.000    0.067    0.000 collections.py:624(_bcast_lwls)
#     17050    0.015    0.000    0.031    0.000 collections.py:657(<listcomp>)
#      8525    0.013    0.000    0.055    0.000 collections.py:662(set_antialiased)
#     17050    0.026    0.000    0.074    0.000 collections.py:691(_set_facecolor)
#      8525    0.006    0.000    0.048    0.000 collections.py:704(set_facecolor)
#     34100    0.005    0.000    0.005    0.000 collections.py:719(get_facecolor)
#     34100    0.011    0.000    0.020    0.000 collections.py:722(get_edgecolor)
#     25575    0.120    0.000    0.652    0.000 collections.py:728(_set_edgecolor)
# ...
#   3116381    0.299    0.000    0.542    0.000 {built-in method builtins.getattr}
#    442394    0.061    0.000    0.073    0.000 {built-in method builtins.hasattr}
# 1334/1022    0.000    0.000    0.001    0.000 {built-in method builtins.hash}
#    563538    0.043    0.000    0.043    0.000 {built-in method builtins.id}
#   3652261    0.389    0.000    0.528    0.000 {built-in method builtins.isinstance}
#    348472    0.051    0.000    0.051    0.000 {built-in method builtins.issubclass}
#    281952    0.059    0.000    0.059    0.000 {built-in method builtins.iter}
# 845838/844583    0.096    0.000    0.097    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#    136728    0.064    0.000    0.065    0.000 {built-in method builtins.max}
#     68256    0.048    0.000    0.048    0.000 {built-in method builtins.min}
#     69387    0.015    0.000    0.060    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.round}
#     18038    0.003    0.000    0.019    0.000 {built-in method builtins.setattr}
#     51436    0.339    0.000    0.339    0.000 {built-in method builtins.sorted}
#  10948262   44.107    0.000   44.108    0.000 {built-in method builtins.sum}
#        52    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#         1    0.000    0.000    0.000    0.000 {built-in method gc.collect}
#     82019    0.033    0.000    0.033    0.000 {built-in method math.ceil}
#        56    0.000    0.000    0.000    0.000 {built-in method math.copysign}
#        12    0.000    0.000    0.000    0.000 {built-in method math.cos}
#       122    0.000    0.000    0.000    0.000 {built-in method math.floor}
#       226    0.000    0.000    0.000    0.000 {built-in method math.log10}
#        24    0.000    0.000    0.000    0.000 {built-in method math.radians}
#        12    0.000    0.000    0.000    0.000 {built-in method math.sin}
#         4    0.076    0.019    0.076    0.019 {built-in method matplotlib._image.resample}
#     17447    0.008    0.000    0.008    0.000 {built-in method matplotlib._path.affine_transform}
#        29    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.get_path_extents}
#         1    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.is_sorted}
#      8530    0.046    0.000    0.051    0.000 {built-in method matplotlib._path.update_path_extents}
#         1    0.025    0.025    0.025    0.025 {built-in method matplotlib._png.write_png}
#    150428    0.277    0.000    0.277    0.000 {built-in method numpy.arange}
# 2182792/2182768    1.939    0.000    1.939    0.000 {built-in method numpy.array}
# 2466831/1647102  134.371    0.000  153.412    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#    164054    0.033    0.000    0.033    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#       399    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#    136780    0.025    0.000    0.025    0.000 {built-in method numpy.geterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#     68390    0.044    0.000    0.044    0.000 {built-in method numpy.seterrobj}
#    128992    0.076    0.000    0.076    0.000 {built-in method numpy.zeros}
#       132    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#        60    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         5    0.028    0.006    0.028    0.006 {built-in method scipy.interpolate.interpnd._ndim_coords_from_arrays}
#      2162    0.001    0.000    0.001    0.000 {built-in method sys._getframe}
#         2    0.000    0.000    0.000    0.000 {built-in method sys.is_finalizing}
#         1    0.000    0.000    0.000    0.000 {built-in method utcnow}
#         1    0.000    0.000    0.000    0.000 {dilate}
#       318    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x7fde02057040}
#    265656    0.045    0.000    0.045    0.000 {function RcParams.__getitem__ at 0x7fdd8fbbe670}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#        18    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#    144943    0.068    0.000    0.450    0.000 {method 'all' of 'numpy.ndarray' objects}
#    181100    0.138    0.000    0.389    0.000 {method 'any' of 'numpy.generic' objects}
#     72745    0.032    0.000    0.138    0.000 {method 'any' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    652858    0.052    0.000    0.052    0.000 {method 'append' of 'list' objects}
#        48    0.466    0.010    0.466    0.010 {method 'argsort' of 'numpy.ndarray' objects}
#    102008    0.113    0.000    0.113    0.000 {method 'astype' of 'numpy.generic' objects}
#    246826    0.372    0.000    0.372    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        60    0.000    0.000    0.000    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#     17110    0.015    0.000    0.334    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#     68204    0.048    0.000    0.048    0.000 {method 'copy' of 'numpy.generic' objects}
#    382672    1.468    0.000    1.468    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        18    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#       274    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#      8525    0.052    0.000    0.052    0.000 {method 'create_contour' of 'matplotlib.QuadContourGenerator' objects}
#         8    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.000    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#         1    0.000    0.000    0.000    0.000 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        12    0.000    0.000    0.000    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         7    0.011    0.002    0.011    0.002 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      8525    0.122    0.000    0.391    0.000 {method 'draw_path_collection' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        12    0.000    0.000    0.000    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         5    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#     68229    0.007    0.000    0.007    0.000 {method 'extend' of 'list' objects}
#        12    0.091    0.008    0.091    0.008 {method 'factorize' of 'pandas._libs.hashtable.Float64HashTable' objects}
#     17232    0.024    0.000    0.024    0.000 {method 'fill' of 'numpy.ndarray' objects}
#    407703    0.340    0.000    0.340    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#       506    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#    472631    0.061    0.000    0.061    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        12    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#        60    0.000    0.000    0.000    0.000 {method 'get_descent' of 'matplotlib.ft2font.FT2Font' objects}
#        24    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#        24    0.373    0.016    0.373    0.016 {method 'get_labels_groupby' of 'pandas._libs.hashtable.Int64HashTable' objects}
#        60    0.001    0.000    0.001    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#        48    0.000    0.000    0.000    0.000 {method 'get_width_height' of 'matplotlib.ft2font.FT2Font' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        18    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         4    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.generic' objects}
#        71    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#   1189676    0.098    0.000    0.098    0.000 {method 'items' of 'dict' objects}
#        36    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#     95296    0.016    0.000    0.016    0.000 {method 'lower' of 'str' objects}
#     53856    0.031    0.000    0.031    0.000 {method 'match' of 're.Pattern' objects}
#     68513    0.033    0.000    0.155    0.000 {method 'max' of 'numpy.ndarray' objects}
#     68333    0.042    0.000    0.191    0.000 {method 'min' of 'numpy.ndarray' objects}
#        70    0.007    0.000    0.007    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        29    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#    292047    0.033    0.000    0.033    0.000 {method 'pop' of 'dict' objects}
#        39    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        30    0.075    0.003    0.075    0.003 {method 'put' of 'numpy.ndarray' objects}
#    133907    0.043    0.000    0.043    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#   1709508    3.427    0.000    3.427    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         9    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#       288    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#     60300    0.038    0.000    0.038    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#    217504    0.519    0.000    0.519    0.000 {method 'round' of 'numpy.generic' objects}
#       185    0.012    0.000    0.012    0.000 {method 'round' of 'numpy.ndarray' objects}
#        29    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        84    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#    232256    0.273    0.000    0.273    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#        60    0.000    0.000    0.000    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#        60    0.002    0.000    0.002    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#        22    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#    116147    8.057    0.000    8.057    0.000 {method 'sort' of 'numpy.ndarray' objects}
#        24    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#      2600    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        82    0.000    0.000    0.027    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#     17142    0.084    0.000    0.084    0.000 {method 'take' of 'numpy.ndarray' objects}
#        31    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#   1134269    0.140    0.000    0.140    0.000 {method 'update' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#     34105    0.006    0.000    0.006    0.000 {method 'values' of 'collections.OrderedDict' objects}
#     94426    0.009    0.000    0.009    0.000 {method 'values' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
# 289881/221673    0.211    0.000    0.552    0.000 {method 'view' of 'numpy.generic' objects}
# 324463/324459    0.128    0.000    1.108    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        30    0.008    0.000    0.008    0.000 {pandas._libs.algos.ensure_float64}
#        60    0.009    0.000    0.009    0.000 {pandas._libs.algos.ensure_int16}
#       223    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#        24    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int8}
#       162    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#        12    0.042    0.004    0.042    0.004 {pandas._libs.algos.groupsort_indexer}
#        24    0.000    0.000    0.000    0.000 {pandas._libs.algos.is_lexsorted}
#       114    0.083    0.001    0.083    0.001 {pandas._libs.algos.take_1d_int64_int64}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_object_object}
#         6    0.012    0.002    0.012    0.002 {pandas._libs.algos.take_2d_axis0_float32_float32}
#         6    0.021    0.003    0.021    0.003 {pandas._libs.algos.take_2d_axis0_float64_float64}
#        30    0.033    0.001    0.033    0.001 {pandas._libs.algos.take_2d_axis1_float32_float32}
#        24    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.clean_index_list}
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.get_reverse_indexer}
#        60    0.000    0.000    0.001    0.000 {pandas._libs.lib.infer_dtype}
#       144    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_complex}
#       102    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#       204    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#       315    0.000    0.000    0.001    0.000 {pandas._libs.lib.is_list_like}
#       360    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#        78    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#        60    0.000    0.000    0.000    0.000 {pandas._libs.lib.values_from_object}

# %% [markdown]
# Dentro da função CCA_visualization, a função que demora mais tempo é a getFrontInWindow

# %%
cProfile.run('CCA_visualization(specificday_mur_aug[:1], days_mur_aug)', 'output.dat')

import pstats
from pstats import SortKey

with open('output_time.txt', 'w') as f:
    p = pstats.Stats('output.dat', stream=f)
    p.sort_stats('time').print_stats()
    
with open('output_calls.txt', 'w') as f:
    p = pstats.Stats('output.dat', stream=f)
    p.sort_stats('calls').print_stats()
# Out:
# /tmp/ipykernel_357230/3445070762.py:164: UserWarning: No contour levels were found within the data range.
#   c = plt.contour(X, Y, w, [thresValue])     #Create and store a set of contour lines or filled regions.
# /tmp/ipykernel_357230/3445070762.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   popBMean = popBSum/popBCount

# %% [markdown]
# ## Line Profiler

# %%
from line_profiler import LineProfiler

profile = LineProfiler(CCA_visualization(specificday_mur_aug[:5], days_mur_aug))

print(profile.print_stats())
# Out:
# /tmp/ipykernel_357230/3445070762.py:164: UserWarning: No contour levels were found within the data range.
#   c = plt.contour(X, Y, w, [thresValue])     #Create and store a set of contour lines or filled regions.
# /tmp/ipykernel_357230/3445070762.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   popBMean = popBSum/popBCount
# Timer unit: 1e-06 s
#
# None
# /tmp/ipykernel_357230/2314377692.py:3: UserWarning: Could not extract a code object for the object None
#   profile = LineProfiler(CCA_visualization(specificday_mur_aug[:5], days_mur_aug))

# %%
# %load_ext line_profiler

# %%
# %lprun -f CCA_visualization CCA_visualization(specificday_mur_aug[:1], days_mur_aug)
# Out:
# /tmp/ipykernel_357230/3445070762.py:164: UserWarning: No contour levels were found within the data range.
#   c = plt.contour(X, Y, w, [thresValue])     #Create and store a set of contour lines or filled regions.
# /tmp/ipykernel_357230/3445070762.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   popBMean = popBSum/popBCount
